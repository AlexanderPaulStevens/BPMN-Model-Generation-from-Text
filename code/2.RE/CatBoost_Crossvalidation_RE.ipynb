# %% [markdown]
# #1. Introduction
# This colab includes crossvalidation, negative sampling, works with the latest feature set and includes **SMOTE** and **RandomOverSample**. V5.2 now supports training the best catboost model for use in the pipeline. The files you need to run this colab are the output of "Feature Generation for CatBoost" in the RE map and "glove.6B.300d.txt" in the "Pre-Trained NER Models Links" file.
#
# This colab is structured as follows:
#
# * ***Section 1*** deals with the loading of the required libraries and the loading of the initial data.
#
# * ***Section 2*** contains the adapted crossvalidation functions for the experiments. No output will be generated if you run this section.
#
# * ***Section 3*** investigates Negative Sampling and the Negative Sampling Rate.
#
# * ***Section 4*** talks about the incorporation of SMOTE into the data enhancement for the use with Catboost.
#
# * ***Section 5*** lays out a brief explanation of RandomOverSampling.
#
# * ***Section 6*** will actually show results from the different crossvalidation functions layed out in section 2.
#
# * ***Section 7*** will save the best model from the crossvalidation using the best under/oversampling method researched in section 6 for use in the pipeline.

# %% [markdown]
# ##1.1. Preliminaries
#
# In this section we install the required packages, load the needed libraries, load the data and load the init functions into memory.

# %%
# !pip install catboost
# !pip install imbalanced-learn
# Out:
# Collecting catboost
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 20.8 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.5
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.12.3)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.5.0)

# %%
# @title Importing Libraries

from catboost import CatBoostClassifier, Pool, metrics, cv
from sklearn.metrics import accuracy_score, f1_score, precision_recall_fscore_support
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, KFold
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from collections import defaultdict
from imblearn.over_sampling import RandomOverSampler
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
import copy


from google.colab import drive

drive.mount('/content/drive/')

#Init variables:
SEED = 42
# Out:
# Mounted at /content/drive/

# %%
# @title These are support functions for Catboost.
def data_preparation(data, SEED):

    X= data.drop('relation_type', axis=1)
    y= data.relation_type

    X_train, X_validation, y_train, y_validation = train_test_split(X, y, train_size=0.80, random_state=SEED)
    #We check for categorical features on the type of the features themselves but also via pd.api which is more rigorous
    categorical_features_indices = [i for i, typ in enumerate(X.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(X.iloc[:, i])]

    return X_train, X_validation, y_train, y_validation, categorical_features_indices

def get_feature_importance(model, train_pool, X_train):
    """
    Get the feature importances from a trained model.

    Parameters:
    - model: The trained model from which to get the feature importances.
    - train_pool: The Pool object used for training the model, containing the training data.
    - X_train: The DataFrame containing the training features, used to get the feature names.

    Returns:
    - features: A dictionary mapping feature names to their importance scores, sorted in descending order of importance.
    """

    feature_importances = model.get_feature_importance(train_pool)
    feature_names = X_train.columns
    features = {}
    for score, name in sorted(zip(feature_importances, feature_names), reverse=True):
        features[name] = score

    return features


def negative_sampling(df_positive, df_negative, R, SEED):
    """
    This function performs negative sampling from a 'negative' dataframe (df_negative)
    for each observation in a 'positive' dataframe (df_positive) by selecting R random
    examples from the negative dataframe without replacement.

    Parameters:
    df_positive (pd.DataFrame): DataFrame containing positive observations.
    df_negative (pd.DataFrame): DataFrame containing negative observations.
    R (int): Number of negative samples to select per positive observation.
    SEED (int): Random seed for reproducibility.

    Returns:
    pd.DataFrame: A new DataFrame containing all observations from df_positive
    followed by the randomly selected observations from df_negative.
    """
    # Setting the random seed for reproducibility
    np.random.seed(SEED)

    # Ensure we do not attempt to sample more items than exist in the negative DataFrame
    """
    if R * len(df_positive) > len(df_negative):
        raise ValueError("Not enough negative samples to fulfill the request without replacement.")"""

    # Sample without replacement a total of R * len(df_positive) items from the negative DataFrame
    total_samples_needed = R * len(df_positive)
    total_samples_needed = int(total_samples_needed)
    sampled_indices = np.random.choice(df_negative.index, size=total_samples_needed, replace=True)
    sampled_negatives = df_negative.loc[sampled_indices].copy()

    # Reset index to avoid index overlap issues when concatenating
    sampled_negatives.reset_index(drop=True, inplace=True)
    df_positive.reset_index(drop=True, inplace=True)

    # Concatenate the positive DataFrame with the sampled negative DataFrame
    result_df = pd.concat([df_positive, sampled_negatives], ignore_index=True)

    return result_df

# %%
# @title Evaluation Functions
def evaluate_model_performance(model, X_val, y_val, SMOTE_check, fold_count,verbose=False):

    # Make predictions on the validation set
    predictions = model.predict(X_val)

    # Calculate the F1 score for verbose output
    if verbose:
        f1_weighted = f1_score(y_val, predictions, average='weighted', zero_division=0)
        print("\n---------------------------------------\n")
        print(f'Weighted F1 Score for all predicted labels: {round(f1_weighted, 4)}')
        print("\n---------------------------------------\n")

        f1_macro = f1_score(y_val, predictions, average='macro', zero_division=0)
        print(f'Macro F1 Score for all predicted labels: {round(f1_macro, 4)}')
        print("\n---------------------------------------\n")

    # Flatten predictions and combine them into a DataFrame
    predictions_flatten = predictions.flatten()
    results_df = pd.DataFrame({'Actual': y_val, 'Predicted': predictions_flatten})

    # Extract unique class labels
    class_labels = np.unique(results_df['Actual'])

    # Calculate label-wise precision, recall, and F1 scores
    P, R, F1, S = precision_recall_fscore_support(results_df['Actual'], results_df['Predicted'], average=None, labels=class_labels, zero_division=0)

    if verbose:
        # Filter out "no_relation" rows if necessary
        filtered_results_df = results_df[results_df['Actual'] != "no_relation"]

        f1_weighted_filtered = f1_score(filtered_results_df['Actual'], filtered_results_df['Predicted'], average='weighted', zero_division=0)
        print(f'Weighted F1 Score (excluding "no_relation"): {round(f1_weighted_filtered, 4)}')
        print("\n---------------------------------------\n")



    # Calculate aggregate precision, recall, and F1 scores
    P_WAggregated, R_WAggregated, F1_WAggregated, _ = precision_recall_fscore_support(results_df['Actual'], results_df['Predicted'], average='weighted', labels=class_labels, zero_division=0)

    P_MAggregated, R_MAggregated, F1_MAggregated, _ = precision_recall_fscore_support(results_df['Actual'], results_df['Predicted'], average='macro', labels=class_labels, zero_division=0)

    P_MicAggregated, R_MicAggregated, F1_MicAggregated, _ = precision_recall_fscore_support(results_df['Actual'], results_df['Predicted'], average='micro', labels=class_labels, zero_division=0)

    metrics_aggregated = {
        'weighted': {
            'Precision': P_WAggregated,
            'Recall': R_WAggregated,
            'F1-Score': F1_WAggregated
        },
        'macro': {
            'Precision': P_MAggregated,
            'Recall': R_MAggregated,
            'F1-Score': F1_MAggregated
        },
        'micro': {
            'Precision': P_MicAggregated,
            'Recall': R_MicAggregated,
            'F1-Score': F1_MicAggregated
        }
    }

    # Create a mapping for individual labels
    metrics_label_mapping = {
        label: {
            'Precision': p,
            'Recall': r,
            'F1-Score': f1,
            'Support': s
        } for label, p, r, f1, s in zip(class_labels, P, R, F1, S)
    }

    if verbose:
      metric_per_label(class_labels, F1, fold_count, SMOTE_check)

    return metrics_label_mapping, metrics_aggregated

# To print out metric per label after each training of a catboost. This takes into account wether we use SMOTE or not.
# Because in the case we use SMOTE a conversion of the numerical label to a string label needs to happen first, as SMOTE needs numerical data.
def metric_per_label(labels, metric, fold_count,check= False):
  if check:

    # Get the class labels from the LabelEncoder, note that this was a global variable.
    original_labels = label_encoder.inverse_transform(labels)

    # Map F1 scores to class labels and display
    f1_scores_label_mapping = dict(zip(original_labels, metric))
    header = "{:<35} {:<15}\n".format("Label", "F1")
    print(header)
    row_format = "{:<35} {:<15}"
    for label, score in f1_scores_label_mapping.items():
        print(row_format.format(label, round(score, 4)))

    """print(f"Metrics per label for fold {fold+1}\n")
        header = "{:<35} {:<15} {:<15} {:<15} {:<15}\n".format("Label", "Precision", "Recall", "F1", "Support")
        print(header)
        for label, metrics in metrics_label.items():
            row_format = "{:<35} {:<15} {:<15} {:<15} {:<15}"
            print(row_format.format(label, "{:.4f}".format(metrics['Precision']), "{:.4f}".format(metrics['Recall']), "{:.4f}".format(metrics['F1-Score']), "{:.0f}".format(metrics['Support'])))"""
  else:
    # Map F1 scores to class labels and display
    f1_scores_label_mapping = dict(zip(labels, metric))
    header = "{:<35} {:<15}\n".format("Label", "F1")
    print(header)
    row_format = "{:<35} {:<15}"
    for label, score in f1_scores_label_mapping.items():
        print(row_format.format(label, round(score, 4)))

# To print out the average metric for each label after crossvalidation
def average_metrics_label(models_and_metrics):
    # Initialize dictionaries to store the sum of the metrics and the count of the metrics for each label
    # lambda is used so in case we try to call a key (label) that does not exist the lambda will create a defaultdict with these values
    sum_metrics = defaultdict(lambda: {'Precision': 0, 'Recall': 0, 'F1-Score': 0, 'Support': 0})
    count_metrics = defaultdict(lambda: {'Precision': 0, 'Recall': 0, 'F1-Score': 0, 'Support': 0})

    # Go through each fold and collect the metrics
    for fold, data in models_and_metrics.items():
        metrics_label = data['metrics_label']
        for label, metrics in metrics_label.items():
            for metric in metrics:
                sum_metrics[label][metric] += metrics[metric]
                count_metrics[label][metric] += 1

    # Calculate the average metrics for each label
    average_metrics = {
        label: {
            metric: sum_metrics[label][metric] / count_metrics[label][metric]
            for metric in sum_metrics[label]
        } for label in sum_metrics
    }
    # Checks if the first key (label) is an integer or not, denoting it has been transformed for SMOTE. If it is an integer we must transform the labels back to a string

    if isinstance(list(average_metrics.keys())[0], (int, np.integer)):
      # Use inverse_transform to get the original labels from encoded keys
      original_labels = label_encoder.inverse_transform(list(average_metrics.keys()))

      # Create a new dictionary with the original labels
      average_metrics = {label: metrics for label, metrics in zip(original_labels, average_metrics.values())}

    # Print the F1 scores for each label
    header = "{:<35} {:<15} {:<15} {:<15}\n".format("Label", "Precision", "Recall", "F1")
    print(header)
    row_format = "{:<35} {:<15} {:<15} {:<15}"
    for label, metrics in average_metrics.items():
        print(row_format.format(label, round(metrics['Precision'], 4), round(metrics['Recall'], 4), round(metrics['F1-Score'], 4)))

# %%
# @title Calculation of Class Weights
def get_catboost_class_weights(series: pd.Series, use_custom=False, SMOTE= False):
    # Define custom weights
    custom_class_weights = {
    'no_relation': 0.8,
    'flow': 1.2,
    'uses': 1.0,
    'actor performer': 1.0,
    'actor recipient': 1.0,
    'further specification': 1.0,
    'same gateway': 1.0
    }
    # Encode the categorical labels to numerical labels
    label_encoder_catboost = LabelEncoder()
    numeric_labels = label_encoder_catboost.fit_transform(series)

    # Compute class weights
    if use_custom and not SMOTE:
        class_weights = custom_class_weights
        #print(class_weights)
        #print("CUSTOM USED")
        return class_weights

    if use_custom and SMOTE:
      # Assume label_encoder is already fitted on the relevant labels
      keys = list(custom_class_weights.keys())

      # Transform the keys into numeric labels
      numeric_keys = label_encoder.transform(keys)

      # Create a new dictionary with numeric labels as keys and the original values
      numeric_class_weights = {numeric_key: custom_class_weights[key] for numeric_key, key in zip(numeric_keys, keys)}
      return numeric_class_weights


    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(numeric_labels), y=numeric_labels)
    print(class_weights)
    print("BALANCED")
    # Map the class weights back to the original categorical labels
    class_weights_dict = {label: class_weights[idx] for idx, label in enumerate(label_encoder_catboost.classes_)}
    print(f"class weights dict {class_weights_dict}")
    return class_weights_dict

# %%
# @title Train Catboost Function
def train_CatBoost(X_train, y_train, X_val, y_val, categorical_features_indices, SEED, test = "ignore",fold_count="ignore", verbose=True, SMOTE_check = False, use_class_weights=False):

    # Compute class weights if applicable
    class_weights = None
    if use_class_weights:
        class_weights = get_catboost_class_weights(pd.concat([y_train, y_val]), True, SMOTE_check)

    # each time X is the features, and Y are the labels.
    # Creating pools for convenience
    train_pool = Pool(X_train, y_train, cat_features=categorical_features_indices)
    validate_pool = Pool(X_val, y_val, cat_features=categorical_features_indices)

    #defining parameters
    params = {
        'iterations': 1500,
        'learning_rate': None,
        'eval_metric': 'MultiClass',
        'random_seed': SEED,
        'logging_level': 'Silent',
        'depth': 8,
        'use_best_model': True, #This gets notably good results
        'loss_function' : 'MultiClass',
        'task_type' : "GPU",
        'devices' : '0',
        'custom_metric': ['F1'],
        'class_weights': class_weights
    }

    model = CatBoostClassifier(**params) #unpacking the params with **

    if type(fold_count) == int:
      print("\n---------------------------------------")
      print(f"\nTraining fold {fold_count+1}...\n")

    if fold_count == "FINAL":
      print("\n---------------------------------------")
      print(f"\nTraining final model...\n")

    if fold_count == "ignore":
      pass

    model.fit(train_pool, eval_set=validate_pool)

    header = "{:<35} {:<15}\n".format("Feature", "Score")
    if verbose:
      print("---------------------------------------")
      print("\nTraining succesfully finished!\n")
      print("---------------------------------------\n")

      print("\nGetting feature importances...\n")

      print(header)

      row_format = "{:<35} {:<15}"
      features_scrores = get_feature_importance(model, train_pool, X_train)
      for name, score in features_scrores.items():
          if score:
            print(row_format.format(name, round(score, 2)))

    # When evaluating sample rate we want to evaluate based on a separate test set. hence the if statements.
    # But when doing crossvalidation we only want scores for the validation set.
    if isinstance(test, pd.DataFrame):
      X_test = test.drop('relation_type', axis=1)
      y_test = test.relation_type
      metrics_label_mapping, metrics_aggregated = evaluate_model_performance(model, X_test, y_test, SMOTE_check, fold_count, verbose)
      return model, metrics_label_mapping, metrics_aggregated
    elif isinstance(test, str):
      metrics_label_mapping, metrics_aggregated = evaluate_model_performance(model, X_val, y_val, SMOTE_check, fold_count, verbose)
      return model, metrics_label_mapping, metrics_aggregated
    else:
        # Raise an error if 'test' is neither a DataFrame nor the string "ignore"
        raise ValueError("The 'test' parameter must be either a DataFrame or the string 'ignore'.")

# %% [markdown]
# ##1.2. Data Loading

# %%
# Define the paths to the PET and LESCHNEIDER data, you get this data by running "Feature Generation for CatBoost".
path1 = '/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TESTING DATA/RE_TRAINING_DATA/total_relation_entity_pairs_DEPENDENCY_CONTEXT_md_PET1.1.csv'
path2 = '/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TESTING DATA/RE_TRAINING_DATA/total_relation_entity_pairs_DEPENDENCY_CONTEXT_md_LESCHNEIDER.csv'

df_PET = pd.read_csv(path1)
df_LESCHNEIDER = pd.read_csv(path2)


total = pd.concat([df_PET, df_LESCHNEIDER], ignore_index=True)
label_counts = total['relation_type'].value_counts()
print(total.head())
# Out:
#   document_name source_token source_type source_pos_tag  source_sentence_ID  \
# 0      doc-10.1          The     B-Actor             DT                   0
# 1      doc-10.1          The     B-Actor             DT                   0
# 2      doc-10.1          The     B-Actor             DT                   0
# 3      doc-10.1          The     B-Actor             DT                   0
# 4      doc-10.1          The     B-Actor             DT                   0
#
#    source_token_ID source_prev_tag source_next_tag target_token  \
# 0                0            NONE      B-Activity        sents
# 1                0            NONE      B-Activity          the
# 2                0            NONE      B-Activity          the
# 3                0            NONE      B-Activity          The
# 4                0            NONE      B-Activity      reviews
#
#        target_type target_pos_tag  target_sentence_ID  target_token_ID  \
# 0       B-Activity            VBZ                   0                2
# 1  B-Activity Data             DT                   0                3
# 2          B-Actor             DT                   0                6
# 3          B-Actor             DT                   1                0
# 4       B-Activity            VBZ                   1                2
#
#   target_prev_tag  target_next_tag  token_distance  sentence_distance  \
# 0         B-Actor  B-Activity Data               2                  0
# 1      B-Activity                O               3                  0
# 2               O                O               6                  0
# 3               O       B-Activity               0                  1
# 4         B-Actor  B-Activity Data               2                  1
#
#   dependency_tags relation_type
# 0             [0]   no_relation
# 1             [0]   no_relation
# 2             [0]   no_relation
# 3             [0]   no_relation
# 4             [0]   no_relation

# %% [markdown]
# #2. Crossvalidation
#
# This separate section is dedicated to the different crossvalidation functions. Since SMOTE and RandomOverSample need a specific data handling approach they have their custom crossvalidation functions.

# %% [markdown]
# ##2.1. Crossvalidation baseline
#
# This is the base crossvalidation code where no special techniques are applied.

# %%
# @title Baseline Crossvalidation Code
def crossvalidation(data, SEED, test_size=0.20, splits=5, use_class_weights = False):

    data_features = data.drop('relation_type', axis=1)
    data_label = data.relation_type

    # Step 1: Prepare group IDs for GroupKFold using the training+validation data
    # Recalculate group IDs to reflect only the groups within train_val_data
    unique_docs = data['document_name'].unique()  # Use pandas to find unique documents
    doc_to_id = {doc_name: i for i, doc_name in enumerate(unique_docs)}
    group_ids = data['document_name'].map(doc_to_id).values

    # Step 2: Initializing GroupKFold Crossvalidation
    #gkf = GroupKFold(n_splits=splits)
    kf = KFold(n_splits=splits, shuffle=True, random_state=SEED)
    #---------
    categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]

    fold_metrics = []

    # Initialize a dictionary to hold models and metrics for each fold, in order to chose the best model.
    models_and_metrics = {}

    # Note that we only make the folds on the development data only meaning the training and validation data are derived from dev data, not touching the test set here.
    for fold, (train_index, val_index) in enumerate(kf.split(X=data_features)):
        X_train, X_val = data_features.iloc[train_index], data_features.iloc[val_index]
        y_train, y_val = data_label.iloc[train_index], data_label.iloc[val_index]

        model, metrics_label, metrics_aggregated = train_CatBoost(X_train, y_train, X_val, y_val, categorical_features_indices, SEED, "ignore", fold, verbose=True, use_class_weights = use_class_weights)

        # Store the model and its aggregated metrics in the dictionary
        models_and_metrics[fold] = {
        "model": model,
        "metrics_label": metrics_label,
        "metrics_aggregated": metrics_aggregated}

        print("\n------------------------")
        print("\nTraining finished, fetching metrics on validation set\n")
        print("------------------------\n")
        print(f"Metrics per label for fold {fold+1}\n")
        header = "{:<35} {:<15} {:<15} {:<15} {:<15}\n".format("Label", "Precision", "Recall", "F1", "Support")
        print(header)
        for label, metrics in metrics_label.items():
            row_format = "{:<35} {:<15} {:<15} {:<15} {:<15}"
            print(row_format.format(label, "{:.4f}".format(metrics['Precision']), "{:.4f}".format(metrics['Recall']), "{:.4f}".format(metrics['F1-Score']), "{:.0f}".format(metrics['Support'])))

        print("------------------------\n")
        print(f"Aggregated metrics fold {fold+1}\n")
        # So it is printed nice
        header = "{:<15} {:<15} {:<15}".format("Micro F1", "Macro F1", "Weighted F1")
        row_format = "{:<15} {:<15} {:<15}".format(
        f"{metrics_aggregated['micro']['F1-Score']:.4f}",
        f"{metrics_aggregated['macro']['F1-Score']:.4f}",
        f"{metrics_aggregated['weighted']['F1-Score']:.4f}")
        print(header)
        print(row_format)

        # We append the list with a tuple
        fold_metrics.append((metrics_aggregated['micro']['F1-Score'], metrics_aggregated['macro']['F1-Score'], metrics_aggregated['weighted']['F1-Score']))

    # After all folds have been processed, select the best model based on the 'macro' F1-Score
    best_fold = max(
        models_and_metrics,
        key=lambda x: models_and_metrics[x]["metrics_aggregated"]["macro"]["F1-Score"]
    )


    best_model = models_and_metrics[best_fold]["model"]

    # Average F1 across all folds
    print("\n------------------------")
    print("------------------------\n")
    print("Crossvalidation finished")
    print(f"\nBest fold {best_fold+1}")
    print("\n------------------------")
    print("------------------------")

    # Convert list of tuples into a NumPy array
    metrics_array = np.array(fold_metrics)

    # Calculate the average of each metric
    avg_micro = np.mean(metrics_array[:, 0])
    avg_macro = np.mean(metrics_array[:, 1])
    avg_weighted = np.mean(metrics_array[:, 2])

    print(f"\nAverage F1 across all folds: \n")
    header = "{:<15} {:<15} {:<15}".format("Micro F1", "Macro F1", "Weighted F1")
    row_format = "{:<15} {:<15} {:<15}".format(
    f"{avg_micro:.4f}",
    f"{avg_macro:.4f}",
    f"{avg_weighted:.4f}")
    print(header)
    print(row_format)
    print("\n------------------------")
    print("------------------------")
    print("AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS\n")
    average_metrics_label(models_and_metrics)
    print("\n------------------------")
    print("------------------------")
    if use_class_weights:
      print("CLASS WEIGHTS USED")
    return best_model

# %% [markdown]
# ##2.2. Crossvalidation Negative Sampling
#
# This code is used to perform Crossvalidation with Negative Sampling of the majority class. Refer to section 3 for further information on the use.

# %%
# @title Negative Sampling Crossvalidation Code
def crossvalidation_neg(train_data, test, SEED, test_size=0.20, splits=5, use_class_weights = False):

    data_features = train_data.drop('relation_type', axis=1)
    data_label = train_data.relation_type

    kf = KFold(n_splits=splits, shuffle=True, random_state=SEED)

    categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]

    fold_metrics = []

    # Initialize a dictionary to hold models and metrics for each fold, in order to chose the best model.
    models_and_metrics = {}

    # Note that we only make the folds on the development data only meaning the training and validation data are derived from dev data, not touching the test set here.
    for fold, (train_index, val_index) in enumerate(kf.split(X=data_features)):
        X_train, X_val = data_features.iloc[train_index], data_features.iloc[val_index]
        y_train, y_val = data_label.iloc[train_index], data_label.iloc[val_index]

        model, metrics_label, metrics_aggregated = train_CatBoost(X_train, y_train, X_val, y_val, categorical_features_indices, SEED, test, fold, verbose=True, SMOTE_check =False, use_class_weights = use_class_weights)

        # Store the model and its aggregated metrics in the dictionary
        models_and_metrics[fold] = {
        "model": model,
        "metrics_label": metrics_label,
        "metrics_aggregated": metrics_aggregated}

        print("\n------------------------")
        print("\nTraining finished, fetching metrics on validation set\n")
        print("------------------------\n")
        print(f"Metrics per label for fold {fold+1}\n")
        header = "{:<35} {:<15} {:<15} {:<15} {:<15}\n".format("Label", "Precision", "Recall", "F1", "Support")
        print(header)
        for label, metrics in metrics_label.items():
            row_format = "{:<35} {:<15} {:<15} {:<15} {:<15}"
            print(row_format.format(label, "{:.4f}".format(metrics['Precision']), "{:.4f}".format(metrics['Recall']), "{:.4f}".format(metrics['F1-Score']), "{:.0f}".format(metrics['Support'])))

        print("------------------------\n")
        print(f"Aggregated metrics fold {fold+1}\n")
        # So it is printed nice
        header = "{:<15} {:<15} {:<15}".format("Micro F1", "Macro F1", "Weighted F1")
        row_format = "{:<15} {:<15} {:<15}".format(
        f"{metrics_aggregated['micro']['F1-Score']:.4f}",
        f"{metrics_aggregated['macro']['F1-Score']:.4f}",
        f"{metrics_aggregated['weighted']['F1-Score']:.4f}")
        print(header)
        print(row_format)

        # We append the list with a tuple
        fold_metrics.append((metrics_aggregated['micro']['F1-Score'], metrics_aggregated['macro']['F1-Score'], metrics_aggregated['weighted']['F1-Score']))

    # After all folds have been processed, select the best model based on the 'macro' F1-Score
    best_fold = max(
        models_and_metrics,
        key=lambda x: models_and_metrics[x]["metrics_aggregated"]["macro"]["F1-Score"]
    )


    best_model = models_and_metrics[best_fold]["model"]

    # Average F1 across all folds
    print("\n------------------------")
    print("------------------------\n")
    print("Crossvalidation finished")
    print(f"\nBest fold {best_fold+1}")
    print("\n------------------------")
    print("------------------------")

    # Convert list of tuples into a NumPy array
    metrics_array = np.array(fold_metrics)

    # Calculate the average of each metric
    avg_micro = np.mean(metrics_array[:, 0])
    avg_macro = np.mean(metrics_array[:, 1])
    avg_weighted = np.mean(metrics_array[:, 2])

    print(f"\nAverage F1 across all folds: \n")
    header = "{:<15} {:<15} {:<15}".format("Micro F1", "Macro F1", "Weighted F1")
    row_format = "{:<15} {:<15} {:<15}".format(
    f"{avg_micro:.4f}",
    f"{avg_macro:.4f}",
    f"{avg_weighted:.4f}")
    print(header)
    print(row_format)
    print("\n------------------------")
    print("------------------------")
    print("AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS\n")
    average_metrics_label(models_and_metrics)
    print("\n------------------------")
    print("------------------------")
    if use_class_weights:
      print("CLASS WEIGHTS USED")

    return best_model

# %% [markdown]
# ##2.3. Crossvalidation with SMOTE
#
# This code is used for Crossvalidation with SMOTE, an upsampling technique for minority classes. See section 4 for more information.

# %% [markdown]
# To that end we need to have a somewhat customized Crossvalidation function, as SMOTE is only applied on the training data and not the validation data after splitting in order to avoid data leaking.

# %%
# @title
def crossvalidation_SMOTE(data, test, SEED, test_size=0.20, splits=5, use_class_weights= False):

    # Assumes that data is preprocessed
    data_features = data.drop('relation_type', axis=1)
    data_label = data.relation_type

    # Initialize SMOTE to only upsample 'flow' to the desired count
    # Calculate current number of 'flow' instances in the training set
    SMOTE_flow = label_encoder.transform(["flow"]).item()
    current_flow_count = data_label.value_counts().get(SMOTE_flow, 0)

    # Set the target to double the current 'flow' count
    desired_flow_count = 2 * current_flow_count # we set to double the flow count

    # Initialize SMOTE
    smote = SMOTE(sampling_strategy={SMOTE_flow: desired_flow_count}, random_state=SEED)

    # Step 2: Initializing regular KFold Crossvalidationkf = KFold(n_splits=splits, shuffle=True, random_state=SEED)
    kf = KFold(n_splits=splits, shuffle=True, random_state=SEED)
    #---------
    categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]

    fold_metrics = []

    # Initialize a dictionary to hold models and metrics for each fold, in order to chose the best model.
    models_and_metrics = {}

    # Note that we only make the folds on the development data only meaning the training and validation data are derived from dev data, not touching the test set here.
    for fold, (train_index, val_index) in enumerate(kf.split(X=data_features)):

        X_train, X_val = data_features.iloc[train_index], data_features.iloc[val_index]
        y_train, y_val = data_label.iloc[train_index], data_label.iloc[val_index]

        # Only make synthetic examples on the training set avoiding data leakage.
        X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

        model, metrics_label, metrics_aggregated = train_CatBoost(X_train_smote, y_train_smote, X_val, y_val, categorical_features_indices, SEED, test, fold, verbose=True, SMOTE_check= True, use_class_weights = use_class_weights)

        # Store the model and its aggregated metrics in the dictionary
        models_and_metrics[fold] = {
        "model": model,
        "metrics_label": metrics_label,
        "metrics_aggregated": metrics_aggregated}

        print("\n------------------------")
        print("\nTraining finished, fetching metrics on validation set...\n")
        print("------------------------\n")

        """print(f"Metrics per label for fold {fold+1}\n")
        header = "{:<35} {:<15} {:<15} {:<15} {:<15}\n".format("Label", "Precision", "Recall", "F1", "Support")
        print(header)
        for label, metrics in metrics_label.items():
            row_format = "{:<35} {:<15} {:<15} {:<15} {:<15}"
            print(row_format.format(label, "{:.4f}".format(metrics['Precision']), "{:.4f}".format(metrics['Recall']), "{:.4f}".format(metrics['F1-Score']), "{:.0f}".format(metrics['Support'])))
        """
        print("------------------------\n")
        print(f"Aggregated metrics fold {fold+1}\n")
        # So it is printed nice
        header = "{:<15} {:<15} {:<15}".format("Micro F1", "Macro F1", "Weighted F1")
        row_format = "{:<15} {:<15} {:<15}".format(
        f"{metrics_aggregated['micro']['F1-Score']:.4f}",
        f"{metrics_aggregated['macro']['F1-Score']:.4f}",
        f"{metrics_aggregated['weighted']['F1-Score']:.4f}")
        print(header)
        print(row_format)

        # We append the list with a tuple
        fold_metrics.append((metrics_aggregated['micro']['F1-Score'], metrics_aggregated['macro']['F1-Score'], metrics_aggregated['weighted']['F1-Score']))

    # After all folds have been processed, select the best model based on the 'macro' F1-Score
    best_fold = max(
        models_and_metrics,
        key=lambda x: models_and_metrics[x]["metrics_aggregated"]["macro"]["F1-Score"]
    )

    best_model = models_and_metrics[best_fold]["model"]

    # Average F1 across all folds
    print("\n------------------------")
    print("------------------------\n")
    print("Crossvalidation finished")
    print(f"\nBest fold {best_fold+1}")
    print("\n------------------------")
    print("------------------------")

    # Convert list of tuples into a NumPy array
    metrics_array = np.array(fold_metrics)

    # Calculate the average of each metric
    avg_micro = np.mean(metrics_array[:, 0])
    avg_macro = np.mean(metrics_array[:, 1])
    avg_weighted = np.mean(metrics_array[:, 2])

    print(f"\nAverage F1 across all folds: \n")
    header = "{:<15} {:<15} {:<15}".format("Micro F1", "Macro F1", "Weighted F1")
    row_format = "{:<15} {:<15} {:<15}".format(
    f"{avg_micro:.4f}",
    f"{avg_macro:.4f}",
    f"{avg_weighted:.4f}")
    print(header)
    print(row_format)
    print("\n------------------------")
    print("------------------------")
    print("AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS\n")
    average_metrics_label(models_and_metrics)
    print("\n------------------------")
    print("------------------------")
    if use_class_weights:
      print("CLASS WEIGHTS USED")

    return best_model

# %% [markdown]
# ##2.4. Crossvalidation with RandomOverSampling
#
# This code is used for Crossvalidation together with RandomOverSampling, an upsampling technique. See section 5 for a brief explanation.

# %%
# @title Crossvalidation with ROS

def crossvalidation_RANDOMOVERSAMPLE(data, SEED, test= "ignore", test_size=0.20, splits=5, use_class_weights= False):

    data_features = data.drop('relation_type', axis=1)
    data_label = data.relation_type

    # Initialize ROS to only upsample 'flow' to the desired count
    # Calculate current number of 'flow' instances in the training set
    current_flow_count = data_label.value_counts().get('flow', 0)

    # Set the target to double the current 'flow' count
    desired_flow_count = 2 * current_flow_count # we double the flow count

    # Create the RandomOverSampler instance
    ros = RandomOverSampler(sampling_strategy={'flow': desired_flow_count}, random_state=SEED)  # Adjust the number as needed

    # Step 2: Initializing regular KFold Crossvalidation
    kf = KFold(n_splits=splits, shuffle=True, random_state=SEED)
    #---------
    categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]

    fold_metrics = []

    # Initialize a dictionary to hold models and metrics for each fold, in order to chose the best model.
    models_and_metrics = {}

    # Note that we only make the folds on the development data only meaning the training and validation data are derived from dev data, not touching the test set here.
    for fold, (train_index, val_index) in enumerate(kf.split(X=data_features)):

        X_train, X_val = data_features.iloc[train_index], data_features.iloc[val_index]
        y_train, y_val = data_label.iloc[train_index], data_label.iloc[val_index]

        # Apply the RandomOverSampler
        X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)

        model, metrics_label, metrics_aggregated = train_CatBoost(X_train_ros, y_train_ros, X_val, y_val, categorical_features_indices, SEED, test, fold, verbose=True, use_class_weights = use_class_weights)

        # Store the model and its aggregated metrics in the dictionary
        models_and_metrics[fold] = {
        "model": model,
        "metrics_label": metrics_label,
        "metrics_aggregated": metrics_aggregated}

        print("\n------------------------")
        print("\nTraining finished, fetching metrics on validation set...\n")
        print("------------------------\n")

        print(f"Metrics per label for fold {fold+1}\n")
        header = "{:<35} {:<15} {:<15} {:<15} {:<15}\n".format("Label", "Precision", "Recall", "F1", "Support")
        print(header)
        for label, metrics in metrics_label.items():
            row_format = "{:<35} {:<15} {:<15} {:<15} {:<15}"
            print(row_format.format(label, "{:.4f}".format(metrics['Precision']), "{:.4f}".format(metrics['Recall']), "{:.4f}".format(metrics['F1-Score']), "{:.0f}".format(metrics['Support'])))

        print("------------------------\n")
        print(f"Aggregated metrics fold {fold+1}\n")
        # So it is printed nice
        header = "{:<15} {:<15} {:<15}".format("Micro F1", "Macro F1", "Weighted F1")
        row_format = "{:<15} {:<15} {:<15}".format(
        f"{metrics_aggregated['micro']['F1-Score']:.4f}",
        f"{metrics_aggregated['macro']['F1-Score']:.4f}",
        f"{metrics_aggregated['weighted']['F1-Score']:.4f}")
        print(header)
        print(row_format)

        # We append the list with a tuple
        fold_metrics.append((metrics_aggregated['micro']['F1-Score'], metrics_aggregated['macro']['F1-Score'], metrics_aggregated['weighted']['F1-Score']))

    # After all folds have been processed, select the best model based on the 'macro' F1-Score
    best_fold = max(
        models_and_metrics,
        key=lambda x: models_and_metrics[x]["metrics_aggregated"]["macro"]["F1-Score"]
    )


    best_model = models_and_metrics[best_fold]["model"]

    # Average F1 across all folds
    print("\n------------------------")
    print("------------------------\n")
    print("Crossvalidation finished")
    print(f"\nBest fold {best_fold+1}")
    print("\n------------------------")
    print("------------------------")

    # Convert list of tuples into a NumPy array
    metrics_array = np.array(fold_metrics)

    # Calculate the average of each metric
    avg_micro = np.mean(metrics_array[:, 0])
    avg_macro = np.mean(metrics_array[:, 1])
    avg_weighted = np.mean(metrics_array[:, 2])

    print(f"\nAverage F1 across all folds: \n")
    header = "{:<15} {:<15} {:<15}".format("Micro F1", "Macro F1", "Weighted F1")
    row_format = "{:<15} {:<15} {:<15}".format(
    f"{avg_micro:.4f}",
    f"{avg_macro:.4f}",
    f"{avg_weighted:.4f}")
    print(header)
    print(row_format)
    print("\n------------------------")
    print("------------------------")
    print("AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS\n")
    average_metrics_label(models_and_metrics)
    print("\n------------------------")
    print("------------------------")
    if use_class_weights:
      print("CLASS WEIGHTS USED")

    return best_model

# %% [markdown]
# #3. Negative Sampling
#
# In this section we investigate the use of an undersampling technique "Negative Sampling" to undersample the majority class "no_relation". Hoping this will yield better results...
#
# ***NOTE: YOU CAN SKIP SECTION 3 WITHOUT AFFECTING THE RUN OF THE COLAB***

# %% [markdown]
# ##3.1. Investigation of appropiate sampling rate

# %% [markdown]
# First, we need to assess at which negative sampling rate the model performs at its best. These are some functions to evaluate the appropiate sampling rates and plotting functions.

# %%
# @title Evaluating Sample Rate and Plotting function
def evaluate_sampling_rate(total, max_R, step, SEED):

    # Initialize results dictionary with lists for metrics and rates, plotting will be done based on this data
    results = {label: {'Precision': [], 'Recall': [], 'F1-Score': [], 'Rates': []}
               for label in np.unique(total['relation_type'])}

    results_aggregated = {'weighted': {'Precision': [], 'Recall': [], 'F1-Score': [], 'Rates': []},
                          'macro': {'Precision': [], 'Recall': [], 'F1-Score': [], 'Rates': []},
                          'micro': {'Precision': [], 'Recall': [], 'F1-Score': [], 'Rates': []}}

    # First we need to split the total dataset into those with and without a relation
    train, test = train_test_split(total, test_size=0.2, stratify=total['relation_type'], random_state=SEED)
    df_true = train[train['relation_type'] != "no_relation"]
    df_no_relation = train[train['relation_type'] == "no_relation"]

    # Iterate over a range of negative sampling rates
    for rate in np.linspace(0.0, max_R, num=int((max_R/step)+1)): # We let the rate start from 1 because if we let it start from 0 the catboost cannot be fit. The reason is that the training set contains no label of 'no_relation' whilst the validation set does.
        # Train the model and retrieve the metrics mapping
        print(f"\rProgress {round(rate/(max_R)*100,2)}% ...", end='  ', flush=True)


        # At each new rate we have to resample the data
        new_data = negative_sampling(df_true, df_no_relation, rate, SEED)
        X_train, X_val, y_train, y_val, categorical_features_indices = data_preparation(new_data, SEED)

        #in order to surpress the printing of the training metrics each time we put the last argument to False
        model, metrics_label, metrics_aggregated = train_CatBoost(X_train, y_train, X_val, y_val, categorical_features_indices, SEED, test,'ignore', False)

        # Iterate over each label in the metrics mapping
        for label in metrics_label.keys():
            p = metrics_label[label]['Precision']
            r = metrics_label[label]['Recall']
            f1 = metrics_label[label]['F1-Score']

            # Append the metrics to the corresponding lists in the results dictionary
            results[label]['Precision'].append(p)
            results[label]['Recall'].append(r)
            results[label]['F1-Score'].append(f1)
            results[label]['Rates'].append(rate)

        # We do the same but we iterate over all types of averaged metrics and not only on label level, averaged will be either 'weighted', 'macro' and 'micro currently.
        for averaged in metrics_aggregated.keys():
            p_a = metrics_aggregated[averaged]['Precision']
            r_a = metrics_aggregated[averaged]['Recall']
            f1_a = metrics_aggregated[averaged]['F1-Score']

            # Append the metrics to the corresponding lists in the results dictionary
            results_aggregated[averaged]['Precision'].append(p_a)
            results_aggregated[averaged]['Recall'].append(r_a)
            results_aggregated[averaged]['F1-Score'].append(f1_a)
            results_aggregated[averaged]['Rates'].append(rate)


    print('--------------------------------')
    print("Evaluation Finished!\n")
    # print('--------------------------------n')

    return results, results_aggregated

def plot_separate_metrics(results, save_path):
    # Set the aesthetic style of the plots
    sns.set_style('darkgrid')

    # Define markers and styles
    markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'X', 'd', '|', '_']
    metric_types = ['Precision', 'Recall', 'F1-Score']
    line_styles = ['-', '--', ':']

    # Get unique colors from Seaborn's palette
    unique_colors = sns.color_palette('husl', n_colors=len(results))

    # Create a separate plot for each metric
    for m_idx, metric in enumerate(metric_types):
        plt.figure(figsize=(12, 6))
        ax = plt.gca()

        #marker=markers[idx % len(markers)],
        for idx, (label, metrics) in enumerate(results.items()):
            color = unique_colors[idx]
            sns.lineplot(x=metrics['Rates'], y=metrics[metric],marker=markers[idx % len(markers)],
                         linestyle=line_styles[m_idx], color=color, ax=ax, label=f'{label} {metric}')

        plt.title(f'{metric} over Negative Sampling Rates')
        plt.xlabel('Negative Sampling Rate (%)')
        plt.ylabel(metric)
        plt.legend(title='Labels', loc='lower right')
        plt.grid(True)
        plt.tight_layout()

        # Save each plot with a unique name based on the metric
        plot_filename = f"{save_path}A.{metric}_labels_plot_OFFICIAL.pdf"
        plt.savefig(plot_filename, bbox_inches='tight')
        plt.show()

def plot_aggregated_metrics(results_aggregated, save_path):

    # Set the aesthetic style of the plots
    sns.set_style('darkgrid')

    # Define the styles and colors
    markers = ['o', '^', 's']  # Different markers for Precision, Recall, F1-Score
    line_styles = ['-', '--', ':']  # Different line styles for Precision, Recall, F1-Score
    metric_labels = ['Precision', 'Recall', 'F1-Score']
    colors = sns.color_palette('husl', n_colors=3)  # Using a hue-based color palette for clear color distinction

    # Iterate over the two types of averaging: Weighted and Macro
    for idx, (key, metrics) in enumerate(results_aggregated.items()):
        # Create a new figure for each type of average
        plt.figure(figsize=(10, 6))
        ax = plt.gca()  # Get current axis

        #marker=markers[m_idx],
        # Plot each metric
        for m_idx, metric in enumerate(metric_labels):
            sns.lineplot(x=metrics['Rates'], y=metrics[metric], linestyle=line_styles[m_idx],
                         color=colors[m_idx], ax=ax, label=f'{metric} ({key.capitalize()})')

        # Enhancing the plot with titles and labels
        plt.title(f'{key.capitalize()} Averages over Negative Sampling Rates')
        plt.xlabel('Negative Sampling Rate (%)')
        plt.ylabel('Metric Value')
        plt.legend(title='Metrics', loc='lower right')
        plt.grid(True)  # Adding grid for better readability

        # Tight layout to ensure neat fitting
        plt.tight_layout()

        # Save the plot to a file
        plot_filename = f"{save_path}B.{key}_averages_plot_OFFICIAL.pdf"
        plt.savefig(plot_filename, bbox_inches='tight')
        plt.show()  # Show the plot in the notebook or script output

# %% [markdown]
# In cells below we try to investigate which negative sampling rate will yield the best performance. We will do this visually.
# This plotting is done specifically to capture the accuracy of **each label** across different metrics. In the next cell you can find the one for the aggregated between all labels.

# %% [markdown]
# ###NOTE: This step is quite resource intensive as you have to train and test the Catboost model $\frac{MAX_R}{STEP}+1$ times. (Aprox 16min on L4 GPU)

# %%
# We are using the above data
max_sampling_rate = 100.0
step = 3
results, results_aggregated = evaluate_sampling_rate(total, max_sampling_rate, step, SEED)
# Out:
# Progress 100.0% ...  --------------------------------
# Evaluation Finished!

# %%
# You only have to give a path where the plots will be saved to, the script dynamically makes a file name
saved_path = '/content/drive/MyDrive/THESIS/DATA/PET/catboost OUTPUTS/'
plot_separate_metrics(results, saved_path)

# %% [markdown]
# Here we plot metrics across all labels. Note that the previous cell has to be run.

# %%
plot_aggregated_metrics(results_aggregated, saved_path)

# %% [markdown]
# #4. SMOTE
#
# From empirical testing we note that "flow" is performing quite poorly, even though this relationship is critical in modelling BPMN models. To adress this issue we will use another technique on top of Negative Sampling in order to improve the metric for this relationship type. The oversampling technique SMOTE will artificially create new instances of "flow" and add it to the training data.

# %% [markdown]
# ##4.1. Pre-Processing
#
# A preprocessing step is essential because it transforms mixed data types into a consistent numerical format suitable for machine learning models. By encoding ordinal and categorical features into numeric values that retain their inherent ordering or categorical nature, the models can accurately compute distances and relationships between data points, which is crucial for techniques like SMOTE to handle imbalanced data and for classifiers to learn meaningful patterns from the features. We use the sklearn OrdinalEncoder for this purpose: to translate the current data type into one that SMOTE can understand.

# %% [markdown]
# GloVe (Global Vectors for Word Representation) is an unsupervised learning algorithm for generating word embeddings by aggregating global word-word co-occurrence statistics from a corpus. It produces vector representations of words where the geometric relationships between the vectors capture semantic relationships between the words.

# %% [markdown]
# Essentially we need GloVe to translate the tokens into a format that is interpretable to SMOTE. The function below will load the pre-trained glove model.

# %%
def load_glove_model(glove_file_path):
    """Load the GloVe model as a dictionary."""
    embedding_dict = {}
    with open(glove_file_path, 'r', encoding='utf8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = list(map(float, values[1:]))
            embedding_dict[word] = vector
    return embedding_dict

# Path to your GloVe file
glove_path = '/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TESTING DATA/RE_TRAINING_DATA/GloVe pre-trained/glove.6B.300d.txt'

# Load the GloVe model
glove_model = load_glove_model(glove_path)

# %%
# @title Pre-Processing functions
def embed_token(token):
    # Return the GloVe vector for a token, or a zero vector if the token is not found.
    vector_size = len(next(iter(glove_model.values())))  # Determine the vector size from the first element
    return glove_model.get(token, np.zeros(vector_size))

# Function to create a DataFrame with embedded vectors for all tokens in a column
def embed_token_column(df, column_name):
    # vector_size = len(next(iter(glove_model.values())))  # Determine the vector size from the first element
    return pd.DataFrame([embed_token(token) for token in df[column_name]],
                        columns=[f'{column_name}_emb_{i}' for i in range(vector_size)],
                        index=df.index)

# Function to preprocess data
def preprocess_data(df):
    # Specify the column groups for encoding
    ordinal_columns = ['source_token_ID', 'source_sentence_ID', 'target_token_ID', 'target_sentence_ID']
    categorical_columns = [
        'source_type', 'source_pos_tag', 'source_prev_tag', 'source_next_tag',
        'target_type', 'target_pos_tag', 'target_prev_tag', 'target_next_tag',
        'dependency_tags', 'document_name'
    ]
    numeric_columns = ['token_distance', 'sentence_distance']

    # Encode non-ordinal categorical columns with OneHotEncoder
    one_hot_df = pd.DataFrame()
    if categorical_columns:
        encoder = OneHotEncoder(sparse=False, drop='first')
        encoded = encoder.fit_transform(df[categorical_columns])
        one_hot_df = pd.DataFrame(encoded, columns=encoder.get_feature_names_out(), index=df['relation_type'])

    one_hot_df = one_hot_df.reset_index(drop=True)

    # Encode ordinal columns with OrdinalEncoder
    ordinal_df = pd.DataFrame()
    if ordinal_columns:
        encoder = OrdinalEncoder()
        encoded = encoder.fit_transform(df[ordinal_columns])
        ordinal_df = pd.DataFrame(encoded, columns=ordinal_columns, index=df.index)

    # Use numeric columns as they are
    numeric_df = df[numeric_columns].copy() if numeric_columns else pd.DataFrame()

    # Embed token columns
    source_token_df = embed_token_column(df, 'source_token')
    target_token_df = embed_token_column(df, 'target_token')

    #Ensure adding the target
    le = LabelEncoder()
    target_label_df = pd.DataFrame(le.fit_transform(df['relation_type']), columns=['relation_type'], index=df['relation_type'])
    target_label_df = target_label_df.reset_index(drop=True)

    # Save the LabelEncoder for later use
    global label_encoder
    label_encoder = le

    assert numeric_df.index.is_unique, "Duplicate indices in numeric_df"
    assert ordinal_df.index.is_unique, "Duplicate indices in ordinal_df"
    assert one_hot_df.index.is_unique, "Duplicate indices in one_hot_df"
    assert source_token_df.index.is_unique, "Duplicate indices in source_token_df"
    assert target_token_df.index.is_unique, "Duplicate indices in target_token_df"
    assert target_label_df.index.is_unique, "Duplicate indices in target_label_df"


    # Concatenate all DataFrames
    df_final = pd.concat([numeric_df, ordinal_df, one_hot_df, source_token_df, target_token_df, target_label_df], axis=1)

    return df_final

# %% [markdown]
# #5. RandomOverSampler
#
# We also experiment with a RandomOverSampler. RandomOverSampler is a technique to address class imbalance in datasets by increasing the number of instances in a (minority) class. It does this by randomly replicating samples from the class until the desired class balance is achieved. The downside is that it tends to overfit to the training data. Since no pre-processing is needed, there is no specific data handling code. See section 2 for the specific crossvalidation code on RandomOverSample.

# %% [markdown]
# #6. Results
#
# This section outlines the results for the Catboost models trained with different data. The data has been modified in each subsection using various techniques.

# %% [markdown]
# ##6.1. Baseline Crossvalidation
#
# Here you can run and consult the result of the baseline Catboost model using crossvalidation without the use of special performance enhancing techniques.

# %%
folds = 5
test_size = 0.2
best_model = crossvalidation(total, SEED, test_size, folds, use_class_weights=True)

# Save the best model to a file
model_path = "/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TRAINED_CATBOOST_MODEL/best_catboost_model.cbm"
best_model.save_model(model_path, format="cbm")
# Out:
# <ipython-input-8-fa9969d7c269>:17: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]
# ---------------------------------------
#
# Training fold 1...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# source_type                         16.32
# sentence_distance                   15.0
# target_type                         13.61
# token_distance                      8.66
# target_token_ID                     6.51
# target_sentence_ID                  5.9
# source_token_ID                     4.94
# target_pos_tag                      4.24
# source_sentence_ID                  3.81
# source_next_tag                     3.67
# source_pos_tag                      3.34
# source_token                        3.02
# target_prev_tag                     2.87
# target_next_tag                     2.53
# source_prev_tag                     2.43
# document_name                       2.18
# target_token                        0.95
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9903
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.797
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8133
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7614
# actor recipient                     0.8454
# flow                                0.5845
# further specification               0.9189
# no_relation                         0.9956
# same gateway                        0.5185
# uses                                0.9547
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 1
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8590          0.6837          0.7614          98
# actor recipient                     0.8542          0.8367          0.8454          49
# flow                                0.6587          0.5253          0.5845          158
# further specification               0.8947          0.9444          0.9189          18
# no_relation                         0.9943          0.9969          0.9956          20113
# same gateway                        0.5833          0.4667          0.5185          15
# uses                                0.9431          0.9667          0.9547          120
# ------------------------
#
# Aggregated metrics fold 1
#
# Micro F1        Macro F1        Weighted F1
# 0.9908          0.7970          0.9903
#
# ---------------------------------------
#
# Training fold 2...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   15.91
# source_type                         14.42
# target_type                         12.78
# source_token_ID                     6.91
# token_distance                      6.89
# target_token_ID                     6.18
# source_pos_tag                      5.75
# target_sentence_ID                  5.14
# source_next_tag                     3.96
# source_sentence_ID                  3.91
# target_pos_tag                      3.84
# source_prev_tag                     3.1
# document_name                       3.07
# source_token                        2.69
# target_prev_tag                     2.0
# target_next_tag                     1.75
# target_token                        1.69
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9905
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7434
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.7989
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.8235
# actor recipient                     0.6667
# flow                                0.6347
# further specification               0.7778
# no_relation                         0.9958
# same gateway                        0.3529
# uses                                0.9524
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 2
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8936          0.7636          0.8235          110
# actor recipient                     0.7692          0.5882          0.6667          34
# flow                                0.8113          0.5212          0.6347          165
# further specification               0.7778          0.7778          0.7778          18
# no_relation                         0.9934          0.9982          0.9958          20103
# same gateway                        1.0000          0.2143          0.3529          14
# uses                                0.9600          0.9449          0.9524          127
# ------------------------
#
# Aggregated metrics fold 2
#
# Micro F1        Macro F1        Weighted F1
# 0.9913          0.7434          0.9905
#
# ---------------------------------------
#
# Training fold 3...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   14.51
# target_type                         12.72
# source_type                         12.34
# token_distance                      7.5
# source_pos_tag                      5.99
# target_token_ID                     5.78
# source_token_ID                     5.42
# target_sentence_ID                  5.31
# target_pos_tag                      5.23
# source_next_tag                     4.64
# source_token                        4.2
# source_sentence_ID                  3.67
# target_next_tag                     3.56
# target_prev_tag                     2.72
# target_token                        2.49
# document_name                       2.34
# source_prev_tag                     1.58
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9902
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.774
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8038
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.8283
# actor recipient                     0.8358
# flow                                0.6107
# further specification               0.8889
# no_relation                         0.9955
# same gateway                        0.3529
# uses                                0.9058
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 3
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.9011          0.7664          0.8283          107
# actor recipient                     0.8235          0.8485          0.8358          33
# flow                                0.7398          0.5200          0.6107          175
# further specification               1.0000          0.8000          0.8889          10
# no_relation                         0.9938          0.9973          0.9955          20125
# same gateway                        0.5000          0.2727          0.3529          11
# uses                                0.8938          0.9182          0.9058          110
# ------------------------
#
# Aggregated metrics fold 3
#
# Micro F1        Macro F1        Weighted F1
# 0.9909          0.7740          0.9902
#
# ---------------------------------------
#
# Training fold 4...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   15.41
# source_type                         14.38
# target_type                         12.26
# token_distance                      8.35
# target_token_ID                     6.83
# target_sentence_ID                  5.72
# target_pos_tag                      5.55
# source_token_ID                     4.75
# source_token                        4.55
# source_pos_tag                      3.93
# source_sentence_ID                  3.64
# target_next_tag                     3.34
# target_prev_tag                     3.1
# source_prev_tag                     2.85
# source_next_tag                     2.71
# document_name                       1.4
# target_token                        1.2
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9909
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.8029
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8201
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.8
# actor recipient                     0.7778
# flow                                0.6027
# further specification               0.878
# no_relation                         0.9958
# same gateway                        0.6154
# uses                                0.9508
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 4
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.7789          0.8222          0.8000          90
# actor recipient                     0.8750          0.7000          0.7778          30
# flow                                0.7040          0.5269          0.6027          167
# further specification               0.9474          0.8182          0.8780          22
# no_relation                         0.9945          0.9971          0.9958          20130
# same gateway                        1.0000          0.4444          0.6154          9
# uses                                0.9587          0.9431          0.9508          123
# ------------------------
#
# Aggregated metrics fold 4
#
# Micro F1        Macro F1        Weighted F1
# 0.9913          0.8029          0.9909
#
# ---------------------------------------
#
# Training fold 5...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   16.04
# target_type                         14.6
# source_type                         12.05
# target_token_ID                     6.72
# token_distance                      6.25
# source_pos_tag                      6.11
# target_sentence_ID                  5.78
# source_token_ID                     4.92
# target_pos_tag                      4.86
# source_token                        4.26
# source_sentence_ID                  3.68
# target_prev_tag                     3.52
# source_next_tag                     3.31
# document_name                       2.73
# target_next_tag                     2.69
# source_prev_tag                     2.0
# target_token                        0.49
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9901
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7715
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.7809
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7845
# actor recipient                     0.7606
# flow                                0.5663
# further specification               0.9143
# no_relation                         0.9956
# same gateway                        0.4444
# uses                                0.9345
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 5
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8659          0.7172          0.7845          99
# actor recipient                     0.7500          0.7714          0.7606          35
# flow                                0.7596          0.4514          0.5663          175
# further specification               0.9412          0.8889          0.9143          18
# no_relation                         0.9937          0.9976          0.9956          20128
# same gateway                        0.4000          0.5000          0.4444          4
# uses                                0.9068          0.9640          0.9345          111
# ------------------------
#
# Aggregated metrics fold 5
#
# Micro F1        Macro F1        Weighted F1
# 0.9909          0.7715          0.9901
#
# ------------------------
# ------------------------
#
# Crossvalidation finished
#
# Best fold 4
#
# ------------------------
# ------------------------
#
# Average F1 across all folds:
#
# Micro F1        Macro F1        Weighted F1
# 0.9910          0.7778          0.9904
#
# ------------------------
# ------------------------
# AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS
#
# Label                               Precision       Recall          F1
#
# actor performer                     0.8597          0.7506          0.7995
# actor recipient                     0.8144          0.749           0.7772
# flow                                0.7347          0.509           0.5998
# further specification               0.9122          0.8459          0.8756
# no_relation                         0.9939          0.9974          0.9957
# same gateway                        0.6967          0.3796          0.4568
# uses                                0.9325          0.9474          0.9397
#
# ------------------------
# ------------------------
# CLASS WEIGHTS USED

# %% [markdown]
# ##6.2. Negative Sampling
#
# Using Negative Sampling on the majority class to modify the data and train a new Catboost Model. From section 3 we concluded that a sampling rate of 15 is appropiate and thus set the sampling_rate to 15.

# %% [markdown]
# ###6.2.1 Negative Sampling Data Creation

# %%
# Run this for init data negative sampling
folds = 5
sampling_rate = 15
test_size = 0.2
train_neg, test_neg = train_test_split(total, test_size=0.2, stratify=total['relation_type'], random_state=SEED)
# Total needs to be the total dataset. We then make the separation again.
df_true_relation = train_neg[train_neg['relation_type'] != "no_relation"]
df_no_relation = train_neg[train_neg['relation_type'] == "no_relation"]
new_data = negative_sampling(df_true_relation, df_no_relation, sampling_rate, SEED)
data_negative_sampling = copy.deepcopy(new_data) #for clarity

# %% [markdown]
# ###6.2.2 Negative Sampling Crossvalidation

# %%
best_model_neg_sample = crossvalidation_neg(data_negative_sampling, test_neg, SEED, test_size, folds, use_class_weights=True)
# Save the best model to a file
model_path = "/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TRAINED_CATBOOST_MODEL/best_catboost_model_using_NEGSAMPLE.cbm"
best_model_neg_sample.save_model(model_path, format="cbm")
# Out:
# <ipython-input-9-ca8ffca765d9>:9: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]
# ---------------------------------------
#
# Training fold 1...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   17.71
# source_type                         15.55
# target_type                         11.83
# token_distance                      8.18
# target_token_ID                     5.12
# source_next_tag                     5.1
# target_pos_tag                      4.82
# source_token_ID                     4.24
# target_sentence_ID                  4.01
# source_pos_tag                      3.98
# source_sentence_ID                  3.41
# target_token                        3.31
# target_prev_tag                     3.03
# document_name                       2.65
# source_token                        2.63
# source_prev_tag                     2.45
# target_next_tag                     1.95
# dependency_tags                     0.02
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9889
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7471
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.838
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7541
# actor recipient                     0.7692
# flow                                0.5952
# further specification               0.9444
# no_relation                         0.9946
# same gateway                        0.25
# uses                                0.9224
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 1
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8415          0.6832          0.7541          101
# actor recipient                     0.7143          0.8333          0.7692          36
# flow                                0.5415          0.6607          0.5952          168
# further specification               0.8947          1.0000          0.9444          17
# no_relation                         0.9953          0.9938          0.9946          20120
# same gateway                        0.4000          0.1818          0.2500          11
# uses                                0.8898          0.9576          0.9224          118
# ------------------------
#
# Aggregated metrics fold 1
#
# Micro F1        Macro F1        Weighted F1
# 0.9887          0.7471          0.9889
#
# ---------------------------------------
#
# Training fold 2...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# source_type                         16.04
# sentence_distance                   14.53
# target_type                         12.34
# token_distance                      6.9
# source_pos_tag                      5.92
# source_token_ID                     5.46
# target_token_ID                     5.18
# target_sentence_ID                  4.16
# target_pos_tag                      3.98
# target_token                        3.76
# source_next_tag                     3.55
# target_next_tag                     3.51
# target_prev_tag                     3.4
# document_name                       3.31
# source_sentence_ID                  2.89
# source_token                        2.65
# source_prev_tag                     2.41
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9891
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7605
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8361
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7283
# actor recipient                     0.6744
# flow                                0.6158
# further specification               0.9091
# no_relation                         0.9948
# same gateway                        0.4706
# uses                                0.9306
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 2
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8072          0.6634          0.7283          101
# actor recipient                     0.5800          0.8056          0.6744          36
# flow                                0.5678          0.6726          0.6158          168
# further specification               0.9375          0.8824          0.9091          17
# no_relation                         0.9956          0.9941          0.9948          20120
# same gateway                        0.6667          0.3636          0.4706          11
# uses                                0.8976          0.9661          0.9306          118
# ------------------------
#
# Aggregated metrics fold 2
#
# Micro F1        Macro F1        Weighted F1
# 0.9889          0.7605          0.9891
#
# ---------------------------------------
#
# Training fold 3...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# source_type                         18.3
# sentence_distance                   14.32
# target_type                         11.17
# token_distance                      6.85
# target_sentence_ID                  4.84
# target_pos_tag                      4.72
# source_token_ID                     4.68
# source_pos_tag                      4.55
# target_token_ID                     4.46
# source_next_tag                     4.36
# target_next_tag                     3.61
# source_token                        3.5
# document_name                       3.47
# source_sentence_ID                  2.98
# target_token                        2.79
# source_prev_tag                     2.78
# target_prev_tag                     2.61
# dependency_tags                     0.0
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9892
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7512
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8513
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7487
# actor recipient                     0.747
# flow                                0.6237
# further specification               0.9143
# no_relation                         0.9948
# same gateway                        0.3077
# uses                                0.9224
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 3
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.7766          0.7228          0.7487          101
# actor recipient                     0.6596          0.8611          0.7470          36
# flow                                0.5686          0.6905          0.6237          168
# further specification               0.8889          0.9412          0.9143          17
# no_relation                         0.9958          0.9937          0.9948          20120
# same gateway                        1.0000          0.1818          0.3077          11
# uses                                0.8898          0.9576          0.9224          118
# ------------------------
#
# Aggregated metrics fold 3
#
# Micro F1        Macro F1        Weighted F1
# 0.9890          0.7512          0.9892
#
# ---------------------------------------
#
# Training fold 4...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# source_type                         15.78
# sentence_distance                   15.19
# target_type                         12.37
# token_distance                      9.12
# source_next_tag                     5.58
# target_pos_tag                      4.88
# target_token_ID                     4.87
# target_sentence_ID                  4.82
# source_pos_tag                      4.19
# source_token_ID                     3.67
# source_token                        3.5
# target_next_tag                     3.31
# source_sentence_ID                  3.28
# document_name                       3.14
# target_prev_tag                     2.48
# source_prev_tag                     2.47
# target_token                        1.37
# dependency_tags                     0.0
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9886
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7256
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8271
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7368
# actor recipient                     0.7407
# flow                                0.595
# further specification               0.9444
# no_relation                         0.9945
# same gateway                        0.1538
# uses                                0.9136
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 4
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.7865          0.6931          0.7368          101
# actor recipient                     0.6667          0.8333          0.7407          36
# flow                                0.5538          0.6429          0.5950          168
# further specification               0.8947          1.0000          0.9444          17
# no_relation                         0.9951          0.9939          0.9945          20120
# same gateway                        0.5000          0.0909          0.1538          11
# uses                                0.8880          0.9407          0.9136          118
# ------------------------
#
# Aggregated metrics fold 4
#
# Micro F1        Macro F1        Weighted F1
# 0.9885          0.7256          0.9886
#
# ---------------------------------------
#
# Training fold 5...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# source_type                         16.5
# sentence_distance                   15.91
# target_type                         13.83
# token_distance                      6.87
# target_pos_tag                      6.22
# target_token_ID                     6.09
# source_pos_tag                      5.41
# target_sentence_ID                  4.28
# source_token_ID                     4.17
# source_next_tag                     3.83
# source_token                        3.33
# source_sentence_ID                  3.13
# source_prev_tag                     2.56
# target_next_tag                     2.52
# target_prev_tag                     2.09
# document_name                       1.86
# target_token                        1.4
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9885
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7637
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8394
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7143
# actor recipient                     0.7209
# flow                                0.5904
# further specification               0.9189
# no_relation                         0.9944
# same gateway                        0.4762
# uses                                0.9306
#
# ------------------------
#
# Training finished, fetching metrics on validation set
#
# ------------------------
#
# Metrics per label for fold 5
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8025          0.6436          0.7143          101
# actor recipient                     0.6200          0.8611          0.7209          36
# flow                                0.5337          0.6607          0.5904          168
# further specification               0.8500          1.0000          0.9189          17
# no_relation                         0.9955          0.9932          0.9944          20120
# same gateway                        0.5000          0.4545          0.4762          11
# uses                                0.8976          0.9661          0.9306          118
# ------------------------
#
# Aggregated metrics fold 5
#
# Micro F1        Macro F1        Weighted F1
# 0.9881          0.7637          0.9885
#
# ------------------------
# ------------------------
#
# Crossvalidation finished
#
# Best fold 5
#
# ------------------------
# ------------------------
#
# Average F1 across all folds:
#
# Micro F1        Macro F1        Weighted F1
# 0.9887          0.7496          0.9889
#
# ------------------------
# ------------------------
# AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS
#
# Label                               Precision       Recall          F1
#
# actor performer                     0.8029          0.6812          0.7364
# actor recipient                     0.6481          0.8389          0.7305
# flow                                0.5531          0.6655          0.604
# further specification               0.8932          0.9647          0.9262
# no_relation                         0.9954          0.9938          0.9946
# same gateway                        0.6133          0.2545          0.3317
# uses                                0.8926          0.9576          0.9239
#
# ------------------------
# ------------------------
# CLASS WEIGHTS USED

# %% [markdown]
# ##6.3 SMOTE
#
# ###6.3.1 SMOTE with Negative Sampling
#
# We perform a crossvalidation on the catboost model that was trained using the negative sampling data created in section 6.2 and enriched it with synthetic examples of 'flow'. For implementation of the crossvalidation see section 2.3.

# %% [markdown]
# First we create new negative sampling data. The total data has to be pre-processed first and then split.

# %%
# Run this for init data negative sampling
folds = 5
sampling_rate = 25
test_size = 0.2

# We first Preprocess the data to prepare it for SMOTE
input_data_smote = preprocess_data(total)

# Then we look for the encoded SMOTE label for 'no_relation', convert it to an integer using .item()
SMOTE_norel_label = label_encoder.transform(["no_relation"]).item()

# ...
train_neg_smote, test_neg_smote = train_test_split(input_data_smote, test_size=0.2, random_state=SEED)

# We then make the separation again.
df_true_relation = train_neg_smote[train_neg_smote['relation_type'] != SMOTE_norel_label]
df_no_relation = train_neg_smote[train_neg_smote['relation_type'] == SMOTE_norel_label]
new_data = negative_sampling(df_true_relation, df_no_relation, sampling_rate, SEED)
data_negative_sampling_SMOTE = copy.deepcopy(new_data) #for clarity

if not data_negative_sampling_SMOTE.empty:
  print("Data Loaded")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Data Loaded

# %%
best_model_SMOTE_neg_sample = crossvalidation_SMOTE(data_negative_sampling_SMOTE, test_neg_smote, SEED, test_size, folds, use_class_weights=True)
# Save the best model to a file
model_path = "/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TRAINED_CATBOOST_MODEL/best_catboost_model_using_SMOTE_NEGSAMPLE.cbm"
best_model_SMOTE_neg_sample.save_model(model_path, format="cbm")
# Out:
# <ipython-input-10-1205813b8751>:22: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]
# ---------------------------------------
#
# Training fold 1...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   19.96
# token_distance                      6.72
# source_type_B-Activity              6.02
# target_type_B-Actor                 4.95
# target_sentence_ID                  2.54
# source_sentence_ID                  2.05
# target_type_B-Activity              2.02
# target_token_ID                     1.98
# target_type_B-XOR Gateway           1.56
# target_prev_tag_O                   1.43
# source_token_ID                     1.43
# target_type_B-Activity Data         1.3
# source_token_emb_278                1.17
# target_pos_tag_IN                   1.02
# source_pos_tag_IN                   1.02
# target_token_emb_9                  0.78
# source_type_B-XOR Gateway           0.73
# target_next_tag_O                   0.72
# target_token_emb_109                0.69
# source_token_emb_242                0.68
# target_next_tag_B-Activity          0.61
# source_token_emb_285                0.58
# target_token_emb_95                 0.55
# source_token_emb_65                 0.52
# target_token_emb_28                 0.52
# target_token_emb_175                0.49
# source_next_tag_O                   0.48
# target_token_emb_183                0.45
# source_prev_tag_O                   0.4
# target_token_emb_221                0.4
# source_token_emb_103                0.39
# target_token_emb_101                0.38
# target_token_emb_51                 0.36
# source_next_tag_B-Condition Specification 0.35
# source_type_B-Condition Specification 0.34
# source_token_emb_276                0.34
# target_token_emb_89                 0.33
# target_token_emb_150                0.32
# target_token_emb_168                0.32
# source_next_tag_B-Activity Data     0.32
# target_type_B-Further Specification 0.3
# source_token_emb_140                0.28
# target_token_emb_214                0.27
# target_token_emb_121                0.27
# target_token_emb_96                 0.27
# source_token_emb_244                0.27
# target_token_emb_298                0.27
# source_token_emb_82                 0.25
# target_next_tag_B-Activity Data     0.25
# source_token_emb_80                 0.24
# target_token_emb_40                 0.24
# source_token_emb_117                0.24
# target_token_emb_152                0.24
# source_token_emb_209                0.24
# target_token_emb_172                0.24
# source_token_emb_230                0.23
# target_token_emb_98                 0.23
# source_token_emb_172                0.23
# source_token_emb_29                 0.23
# target_token_emb_75                 0.22
# source_token_emb_156                0.22
# target_token_emb_70                 0.22
# target_token_emb_285                0.22
# target_token_emb_135                0.22
# target_token_emb_169                0.22
# target_token_emb_83                 0.22
# source_token_emb_153                0.21
# source_token_emb_258                0.21
# target_token_emb_34                 0.21
# source_token_emb_180                0.2
# source_token_emb_296                0.2
# target_token_emb_245                0.19
# source_token_emb_167                0.19
# source_token_emb_35                 0.19
# target_token_emb_196                0.19
# target_token_emb_242                0.19
# target_token_emb_64                 0.19
# source_token_emb_224                0.19
# source_pos_tag_VBN                  0.19
# target_token_emb_21                 0.18
# source_token_emb_45                 0.18
# source_token_emb_200                0.18
# source_pos_tag_RB                   0.18
# target_token_emb_78                 0.18
# source_token_emb_163                0.18
# source_token_emb_187                0.17
# target_token_emb_146                0.17
# source_type_B-Actor                 0.17
# source_token_emb_197                0.16
# target_token_emb_251                0.16
# source_token_emb_290                0.16
# target_token_emb_177                0.16
# source_token_emb_114                0.15
# target_next_tag_B-Condition Specification 0.15
# target_token_emb_182                0.15
# source_token_emb_222                0.15
# target_prev_tag_B-Actor             0.15
# source_token_emb_177                0.15
# target_token_emb_206                0.15
# source_token_emb_58                 0.15
# source_token_emb_169                0.14
# source_token_emb_196                0.14
# target_token_emb_167                0.14
# target_token_emb_82                 0.14
# target_token_emb_114                0.14
# target_token_emb_81                 0.14
# source_token_emb_53                 0.14
# target_token_emb_54                 0.14
# target_token_emb_137                0.14
# target_token_emb_261                0.14
# source_prev_tag_B-XOR Gateway       0.14
# source_token_emb_61                 0.14
# target_token_emb_230                0.13
# target_token_emb_249                0.13
# target_token_emb_23                 0.12
# target_token_emb_124                0.12
# target_token_emb_176                0.12
# source_token_emb_23                 0.12
# source_token_emb_92                 0.12
# source_token_emb_69                 0.12
# source_token_emb_191                0.12
# target_token_emb_143                0.12
# target_token_emb_45                 0.12
# source_token_emb_17                 0.12
# source_token_emb_88                 0.12
# source_token_emb_84                 0.12
# source_token_emb_250                0.12
# target_token_emb_48                 0.12
# target_token_emb_35                 0.12
# target_token_emb_181                0.11
# source_token_emb_150                0.11
# target_token_emb_84                 0.11
# source_token_emb_255                0.11
# source_token_emb_63                 0.11
# source_token_emb_94                 0.11
# target_token_emb_65                 0.11
# source_token_emb_299                0.11
# source_token_emb_220                0.1
# source_token_emb_50                 0.1
# source_token_emb_8                  0.1
# source_token_emb_237                0.1
# source_prev_tag_B-Actor             0.1
# source_token_emb_254                0.1
# target_token_emb_281                0.1
# target_token_emb_188                0.1
# source_token_emb_225                0.1
# source_token_emb_246                0.1
# source_token_emb_102                0.1
# source_token_emb_135                0.1
# target_token_emb_80                 0.1
# source_token_emb_109                0.1
# target_token_emb_1                  0.1
# source_token_emb_127                0.09
# source_token_emb_99                 0.09
# source_token_emb_12                 0.09
# source_token_emb_229                0.09
# target_token_emb_278                0.09
# source_token_emb_238                0.09
# source_pos_tag_DT                   0.09
# target_token_emb_266                0.09
# source_token_emb_288                0.09
# source_token_emb_158                0.09
# source_token_emb_261                0.09
# source_token_emb_145                0.09
# target_token_emb_139                0.09
# source_token_emb_19                 0.09
# target_token_emb_232                0.09
# source_token_emb_0                  0.09
# target_token_emb_4                  0.09
# target_token_emb_122                0.08
# target_token_emb_2                  0.08
# target_pos_tag_DT                   0.08
# target_token_emb_170                0.08
# source_token_emb_263                0.08
# target_token_emb_126                0.08
# source_token_emb_236                0.08
# source_token_emb_48                 0.08
# source_token_emb_89                 0.08
# target_token_emb_257                0.08
# source_token_emb_4                  0.08
# source_token_emb_101                0.08
# source_token_emb_181                0.08
# target_token_emb_211                0.08
# target_token_emb_119                0.08
# target_token_emb_102                0.08
# source_token_emb_105                0.08
# source_type_B-Activity Data         0.08
# target_token_emb_282                0.08
# target_token_emb_94                 0.08
# target_token_emb_33                 0.08
# target_token_emb_25                 0.08
# source_token_emb_100                0.07
# source_token_emb_293                0.07
# target_token_emb_255                0.07
# source_token_emb_262                0.07
# target_token_emb_46                 0.07
# source_token_emb_297                0.07
# target_token_emb_92                 0.07
# target_token_emb_180                0.07
# source_token_emb_76                 0.07
# target_token_emb_87                 0.07
# target_token_emb_77                 0.07
# source_token_emb_67                 0.07
# source_token_emb_124                0.07
# target_token_emb_145                0.07
# target_token_emb_269                0.07
# target_token_emb_20                 0.06
# source_token_emb_185                0.06
# target_token_emb_43                 0.06
# source_token_emb_189                0.06
# document_name_doc-2.2               0.06
# target_token_emb_49                 0.06
# source_token_emb_281                0.06
# source_token_emb_128                0.06
# source_token_emb_90                 0.06
# target_token_emb_179                0.06
# target_token_emb_130                0.06
# target_token_emb_147                0.06
# source_token_emb_85                 0.06
# source_token_emb_46                 0.06
# target_token_emb_118                0.06
# source_token_emb_142                0.06
# source_token_emb_107                0.06
# target_token_emb_32                 0.06
# target_token_emb_224                0.06
# source_token_emb_226                0.06
# source_next_tag_B-Actor             0.06
# source_token_emb_215                0.06
# source_token_emb_15                 0.06
# target_token_emb_296                0.06
# target_token_emb_208                0.06
# target_token_emb_154                0.06
# target_token_emb_217                0.06
# source_token_emb_269                0.05
# source_token_emb_298                0.05
# target_token_emb_44                 0.05
# source_token_emb_154                0.05
# source_token_emb_274                0.05
# target_token_emb_198                0.05
# target_next_tag_B-Actor             0.05
# source_token_emb_55                 0.05
# source_token_emb_5                  0.05
# target_token_emb_276                0.05
# target_token_emb_191                0.05
# source_token_emb_199                0.05
# source_token_emb_160                0.05
# source_token_emb_144                0.05
# target_token_emb_246                0.05
# target_token_emb_267                0.05
# source_token_emb_73                 0.05
# target_token_emb_200                0.05
# source_token_emb_108                0.05
# target_token_emb_105                0.05
# target_token_emb_260                0.05
# target_token_emb_27                 0.05
# source_token_emb_213                0.05
# source_token_emb_192                0.05
# source_token_emb_294                0.05
# source_token_emb_171                0.05
# target_token_emb_72                 0.05
# target_token_emb_93                 0.05
# target_token_emb_239                0.05
# source_token_emb_59                 0.05
# target_token_emb_60                 0.05
# source_token_emb_122                0.05
# target_token_emb_234                0.05
# source_token_emb_26                 0.05
# source_token_emb_208                0.05
# source_token_emb_259                0.05
# source_token_emb_151                0.05
# source_token_emb_291                0.05
# target_token_emb_110                0.05
# target_token_emb_131                0.05
# target_pos_tag_RB                   0.05
# source_token_emb_235                0.05
# source_token_emb_16                 0.05
# target_token_emb_162                0.05
# target_token_emb_174                0.05
# source_token_emb_87                 0.04
# source_token_emb_54                 0.04
# target_token_emb_248                0.04
# target_pos_tag_WRB                  0.04
# target_token_emb_144                0.04
# source_token_emb_295                0.04
# source_token_emb_280                0.04
# target_token_emb_56                 0.04
# source_token_emb_9                  0.04
# source_token_emb_91                 0.04
# target_token_emb_231                0.04
# source_token_emb_248                0.04
# target_token_emb_38                 0.04
# target_token_emb_88                 0.04
# target_pos_tag_VBG                  0.04
# target_token_emb_250                0.04
# target_token_emb_29                 0.04
# source_token_emb_39                 0.04
# source_next_tag_B-Activity          0.04
# target_token_emb_247                0.04
# source_token_emb_131                0.04
# target_token_emb_244                0.04
# source_token_emb_143                0.04
# target_token_emb_129                0.04
# target_token_emb_63                 0.04
# source_token_emb_62                 0.04
# source_token_emb_42                 0.04
# target_token_emb_290                0.04
# source_token_emb_204                0.04
# target_token_emb_31                 0.04
# target_token_emb_15                 0.04
# source_pos_tag_VBZ                  0.04
# source_token_emb_72                 0.04
# source_token_emb_286                0.04
# source_token_emb_174                0.04
# target_token_emb_6                  0.04
# target_token_emb_227                0.04
# source_token_emb_194                0.04
# target_token_emb_171                0.04
# target_token_emb_13                 0.04
# target_token_emb_193                0.04
# document_name_doc-1.2               0.04
# source_token_emb_111                0.04
# source_token_emb_273                0.04
# target_token_emb_112                0.04
# target_token_emb_273                0.04
# source_token_emb_219                0.04
# target_token_emb_222                0.03
# source_token_emb_279                0.03
# source_token_emb_232                0.03
# source_token_emb_49                 0.03
# source_token_emb_130                0.03
# target_token_emb_279                0.03
# source_token_emb_162                0.03
# target_token_emb_241                0.03
# source_token_emb_198                0.03
# target_token_emb_219                0.03
# source_token_emb_123                0.03
# target_token_emb_209                0.03
# source_token_emb_66                 0.03
# target_token_emb_50                 0.03
# target_token_emb_265                0.03
# target_token_emb_14                 0.03
# source_token_emb_2                  0.03
# source_token_emb_13                 0.03
# source_token_emb_176                0.03
# source_token_emb_37                 0.03
# target_token_emb_237                0.03
# target_token_emb_115                0.03
# source_token_emb_106                0.03
# target_token_emb_284                0.03
# source_token_emb_139                0.03
# target_token_emb_151                0.03
# document_name_doc-5.3               0.03
# document_name_doc-3.5               0.03
# target_token_emb_107                0.03
# target_pos_tag_VBZ                  0.03
# source_token_emb_112                0.03
# source_token_emb_239                0.03
# target_token_emb_5                  0.03
# source_token_emb_38                 0.03
# source_token_emb_137                0.03
# source_token_emb_221                0.03
# target_token_emb_164                0.03
# target_token_emb_212                0.03
# target_token_emb_149                0.03
# target_token_emb_116                0.03
# target_token_emb_161                0.03
# source_token_emb_152                0.03
# source_token_emb_21                 0.03
# source_token_emb_205                0.03
# target_token_emb_289                0.03
# source_token_emb_78                 0.03
# target_token_emb_90                 0.03
# source_token_emb_40                 0.03
# target_token_emb_59                 0.03
# target_token_emb_141                0.03
# target_token_emb_218                0.03
# source_token_emb_71                 0.02
# source_token_emb_133                0.02
# source_token_emb_110                0.02
# target_token_emb_286                0.02
# source_token_emb_47                 0.02
# target_token_emb_113                0.02
# source_token_emb_277                0.02
# target_token_emb_99                 0.02
# source_pos_tag_VB                   0.02
# target_token_emb_192                0.02
# source_token_emb_179                0.02
# target_token_emb_148                0.02
# target_token_emb_203                0.02
# source_token_emb_51                 0.02
# target_token_emb_7                  0.02
# target_token_emb_30                 0.02
# source_token_emb_173                0.02
# target_token_emb_199                0.02
# source_pos_tag_NNP                  0.02
# source_token_emb_155                0.02
# source_token_emb_270                0.02
# target_token_emb_252                0.02
# source_pos_tag_VBD                  0.02
# target_token_emb_104                0.02
# source_token_emb_75                 0.02
# target_token_emb_160                0.02
# source_token_emb_25                 0.02
# target_token_emb_69                 0.02
# target_token_emb_24                 0.02
# target_token_emb_86                 0.02
# source_token_emb_193                0.02
# source_token_emb_282                0.02
# target_token_emb_47                 0.02
# document_name_doc-9.2               0.02
# target_token_emb_184                0.02
# target_token_emb_272                0.02
# source_token_emb_95                 0.02
# target_prev_tag_B-Activity Data     0.02
# source_token_emb_86                 0.02
# source_token_emb_245                0.02
# target_token_emb_197                0.02
# target_token_emb_166                0.02
# source_token_emb_241                0.02
# source_token_emb_247                0.02
# source_token_emb_210                0.02
# target_token_emb_22                 0.02
# target_token_emb_165                0.02
# target_token_emb_42                 0.02
# source_token_emb_289                0.02
# target_token_emb_111                0.02
# source_token_emb_214                0.02
# target_token_emb_256                0.02
# target_token_emb_186                0.02
# source_token_emb_60                 0.02
# source_token_emb_6                  0.02
# source_token_emb_20                 0.02
# source_token_emb_184                0.02
# target_prev_tag_NONE                0.02
# target_token_emb_138                0.02
# target_token_emb_26                 0.02
# source_token_emb_119                0.02
# source_token_emb_136                0.02
# target_token_emb_61                 0.02
# target_token_emb_243                0.02
# target_token_emb_236                0.02
# source_token_emb_98                 0.02
# source_token_emb_218                0.02
# target_token_emb_140                0.02
# target_token_emb_36                 0.02
# target_token_emb_173                0.02
# source_token_emb_188                0.02
# source_token_emb_36                 0.02
# target_pos_tag_NNP                  0.02
# source_token_emb_252                0.02
# source_token_emb_24                 0.02
# target_token_emb_259                0.01
# source_token_emb_231                0.01
# source_token_emb_292                0.01
# target_token_emb_117                0.01
# target_token_emb_125                0.01
# target_token_emb_228                0.01
# source_token_emb_149                0.01
# source_token_emb_41                 0.01
# target_token_emb_225                0.01
# target_token_emb_207                0.01
# source_token_emb_166                0.01
# document_name_doc-4.1               0.01
# source_token_emb_170                0.01
# target_token_emb_223                0.01
# source_token_emb_186                0.01
# source_token_emb_27                 0.01
# source_token_emb_267                0.01
# target_token_emb_123                0.01
# source_token_emb_18                 0.01
# target_token_emb_39                 0.01
# source_token_emb_264                0.01
# document_name_doc-9.5               0.01
# source_token_emb_182                0.01
# target_token_emb_204                0.01
# source_token_emb_275                0.01
# source_token_emb_93                 0.01
# source_token_emb_164                0.01
# target_token_emb_73                 0.01
# source_token_emb_260                0.01
# source_token_emb_1                  0.01
# source_token_emb_33                 0.01
# source_token_emb_141                0.01
# source_pos_tag_VBG                  0.01
# target_pos_tag_NN                   0.01
# target_token_emb_37                 0.01
# target_token_emb_16                 0.01
# source_token_emb_234                0.01
# source_token_emb_22                 0.01
# target_token_emb_19                 0.01
# source_pos_tag_VBP                  0.01
# target_token_emb_127                0.01
# target_token_emb_74                 0.01
# target_token_emb_163                0.01
# target_token_emb_17                 0.01
# source_token_emb_44                 0.01
# source_token_emb_14                 0.01
# target_token_emb_133                0.01
# source_token_emb_118                0.01
# source_token_emb_81                 0.01
# source_token_emb_287                0.01
# source_token_emb_211                0.01
# target_token_emb_297                0.01
# target_token_emb_136                0.01
# target_token_emb_41                 0.01
# document_name_doc-20.13 - thesis writing 0.01
# target_token_emb_201                0.01
# target_token_emb_103                0.01
# source_pos_tag_NNS                  0.01
# source_token_emb_148                0.01
# target_pos_tag_PRP                  0.01
# target_token_emb_270                0.01
# target_token_emb_202                0.01
# target_token_emb_153                0.01
# target_token_emb_8                  0.01
# source_token_emb_207                0.01
# source_token_emb_206                0.01
# target_token_emb_3                  0.01
# target_token_emb_156                0.01
# source_pos_tag_JJ                   0.01
# target_token_emb_295                0.01
# target_token_emb_258                0.01
# source_token_emb_125                0.01
# target_token_emb_185                0.01
# source_prev_tag_B-Further Specification 0.01
# target_token_emb_190                0.01
# document_name_doc-7.1               0.01
# target_token_emb_220                0.01
# source_token_emb_268                0.01
# target_token_emb_52                 0.01
# source_token_emb_77                 0.01
# source_token_emb_253                0.01
# target_token_emb_79                 0.01
# source_token_emb_257                0.01
# source_token_emb_57                 0.01
# source_token_emb_251                0.01
# target_token_emb_240                0.01
# source_prev_tag_B-Activity Data     0.01
# target_token_emb_18                 0.01
# source_token_emb_183                0.01
# source_token_emb_113                0.01
# source_token_emb_7                  0.01
# source_token_emb_217                0.01
# target_token_emb_57                 0.01
# target_token_emb_67                 0.01
# source_token_emb_43                 0.01
# document_name_doc-9.1               0.01
# source_token_emb_68                 0.01
# target_prev_tag_B-Further Specification 0.01
# document_name_doc-20.5 - edit pictures 0.01
# source_token_emb_126                0.01
# source_token_emb_243                0.01
# source_token_emb_64                 0.01
# document_name_doc-10.11             0.01
# source_token_emb_223                0.01
# document_name_doc-5.1               0.01
# document_name_doc-20.3 - project manager approval 0.01
# source_token_emb_104                0.01
# source_token_emb_272                0.0
# source_token_emb_3                  0.0
# document_name_doc-1.3               0.0
# source_pos_tag_MD                   0.0
# source_token_emb_52                 0.0
# target_token_emb_58                 0.0
# source_token_emb_161                0.0
# source_token_emb_178                0.0
# source_token_emb_56                 0.0
# source_token_emb_79                 0.0
# document_name_doc-20.14 - HR interview 0.0
# target_token_emb_268                0.0
# document_name_doc-20.10 - ISP student 0.0
# target_token_emb_216                0.0
# target_token_emb_299                0.0
# source_token_emb_212                0.0
# target_token_emb_291                0.0
# source_token_emb_165                0.0
# source_token_emb_28                 0.0
# target_token_emb_108                0.0
# source_token_emb_146                0.0
# target_token_emb_0                  0.0
# target_token_emb_293                0.0
# source_token_emb_120                0.0
# target_token_emb_195                0.0
# target_token_emb_226                0.0
# target_token_emb_66                 0.0
# document_name_doc-10.3              0.0
# source_token_emb_228                0.0
# source_token_emb_227                0.0
# source_token_emb_283                0.0
# source_token_emb_83                 0.0
# document_name_doc-20.9 - complaint process model 0.0
# target_token_emb_128                0.0
# source_token_emb_201                0.0
# target_token_emb_229                0.0
# source_token_emb_265                0.0
# target_token_emb_12                 0.0
# document_name_doc-9.3               0.0
# source_token_emb_34                 0.0
# source_token_emb_134                0.0
# source_token_emb_256                0.0
# target_token_emb_205                0.0
# target_token_emb_238                0.0
# source_token_emb_233                0.0
# document_name_doc-6.3               0.0
# document_name_doc-20.4 - procurement process 0.0
# target_token_emb_283                0.0
# source_token_emb_138                0.0
# target_prev_tag_B-Condition Specification 0.0
# target_token_emb_178                0.0
# target_pos_tag_VBP                  0.0
# document_name_doc-20.2 - employee project approval 0.0
# source_token_emb_74                 0.0
# target_token_emb_97                 0.0
# document_name_doc-8.2               0.0
# target_next_tag_B-XOR Gateway       0.0
# target_token_emb_134                0.0
# source_token_emb_168                0.0
# document_name_doc-20.7 - marketing team 0.0
# target_token_emb_68                 0.0
# document_name_doc-8.1               0.0
# target_token_emb_215                0.0
# target_token_emb_288                0.0
# document_name_doc-20.1 - order shipping 0.0
# source_token_emb_70                 0.0
# source_token_emb_115                0.0
# document_name_doc-3.7               0.0
# target_token_emb_253                0.0
# target_token_emb_132                0.0
# document_name_doc-8.3               0.0
# target_token_emb_287                0.0
# document_name_doc-20.12 - horse riding lesson 0.0
# source_token_emb_97                 0.0
# source_token_emb_129                0.0
# source_token_emb_132                0.0
# target_token_emb_100                0.0
# document_name_doc-3.6               0.0
# target_token_emb_10                 0.0
# target_token_emb_294                0.0
# target_token_emb_235                0.0
# document_name_doc-20.11 - credit risk assessment 0.0
# source_token_emb_175                0.0
# source_token_emb_116                0.0
# target_token_emb_210                0.0
# source_token_emb_195                0.0
# dependency_tags_[2, 14]             0.0
# target_token_emb_55                 0.0
# dependency_tags_[11, 61]            0.0
# document_name_doc-10.7              0.0
# target_token_emb_189                0.0
# source_token_emb_32                 0.0
# target_token_emb_263                0.0
# source_token_emb_271                0.0
# document_name_doc-6.2               0.0
# dependency_tags_[55, 61, 41]        0.0
# target_pos_tag_UH                   0.0
# source_token_emb_10                 0.0
# source_pos_tag_WRB                  0.0
# target_pos_tag_MD                   0.0
# dependency_tags_[61, 14]            0.0
# source_token_emb_147                0.0
# source_token_emb_266                0.0
# target_token_emb_85                 0.0
# dependency_tags_[42, 61, 14]        0.0
# target_pos_tag_PDT                  0.0
# target_token_emb_271                0.0
# dependency_tags_[55, 50, 1]         0.0
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9884
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7899
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.9884
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7407
# actor recipient                     0.875
# flow                                0.5109
# further specification               0.8947
# no_relation                         0.9943
# same gateway                        0.5625
# uses                                0.9512
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# ------------------------
#
# Aggregated metrics fold 1
#
# Micro F1        Macro F1        Weighted F1
# 0.9884          0.7899          0.9884
#
# ---------------------------------------
#
# Training fold 2...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   18.88
# token_distance                      5.91
# target_type_B-Actor                 5.44
# source_type_B-Activity              3.69
# target_sentence_ID                  3.56
# source_sentence_ID                  2.91
# target_token_ID                     2.45
# target_type_B-XOR Gateway           1.79
# target_type_B-Activity Data         1.75
# source_token_ID                     1.56
# target_type_B-Activity              1.49
# source_type_B-XOR Gateway           1.29
# source_pos_tag_IN                   0.97
# target_token_emb_282                0.8
# target_next_tag_O                   0.79
# target_token_emb_244                0.76
# source_token_emb_239                0.72
# target_next_tag_B-Activity          0.7
# target_token_emb_276                0.65
# source_token_emb_272                0.5
# target_prev_tag_O                   0.5
# source_token_emb_45                 0.48
# source_token_emb_65                 0.46
# source_token_emb_180                0.46
# source_next_tag_B-Condition Specification 0.46
# source_token_emb_82                 0.43
# target_token_emb_99                 0.43
# target_token_emb_147                0.42
# target_token_emb_101                0.42
# target_token_emb_75                 0.41
# source_next_tag_O                   0.41
# source_type_B-Condition Specification 0.4
# source_next_tag_B-Activity Data     0.4
# source_token_emb_188                0.38
# source_token_emb_185                0.38
# source_token_emb_184                0.37
# source_token_emb_114                0.37
# source_token_emb_1                  0.36
# target_token_emb_278                0.35
# target_token_emb_34                 0.35
# source_token_emb_153                0.34
# target_token_emb_209                0.33
# source_pos_tag_DT                   0.33
# target_token_emb_281                0.32
# source_pos_tag_VBN                  0.32
# source_token_emb_183                0.31
# source_token_emb_63                 0.31
# source_token_emb_179                0.3
# source_token_emb_92                 0.3
# target_token_emb_200                0.29
# target_token_emb_198                0.29
# source_token_emb_227                0.29
# source_token_emb_122                0.28
# target_token_emb_67                 0.28
# target_token_emb_153                0.27
# target_token_emb_124                0.25
# target_token_emb_250                0.25
# target_token_emb_184                0.25
# target_pos_tag_IN                   0.25
# target_token_emb_213                0.25
# target_token_emb_169                0.25
# target_token_emb_114                0.24
# target_token_emb_206                0.23
# source_token_emb_192                0.23
# target_token_emb_71                 0.23
# target_next_tag_B-Condition Specification 0.23
# target_token_emb_135                0.22
# target_token_emb_131                0.22
# target_token_emb_152                0.21
# target_token_emb_89                 0.21
# target_token_emb_9                  0.2
# source_token_emb_13                 0.2
# target_token_emb_48                 0.19
# source_token_emb_28                 0.19
# source_token_emb_229                0.19
# source_token_emb_217                0.19
# source_token_emb_200                0.18
# source_token_emb_121                0.18
# source_token_emb_64                 0.18
# source_token_emb_123                0.18
# source_token_emb_247                0.17
# target_token_emb_121                0.17
# target_token_emb_61                 0.17
# source_token_emb_154                0.17
# target_type_B-Further Specification 0.17
# target_token_emb_74                 0.16
# source_token_emb_260                0.16
# source_token_emb_117                0.16
# source_token_emb_236                0.16
# target_token_emb_170                0.16
# target_token_emb_98                 0.16
# target_token_emb_127                0.16
# target_token_emb_3                  0.16
# source_token_emb_267                0.15
# target_token_emb_70                 0.15
# source_token_emb_61                 0.15
# source_token_emb_135                0.15
# source_token_emb_21                 0.15
# source_token_emb_278                0.14
# target_token_emb_23                 0.14
# source_token_emb_131                0.14
# target_token_emb_266                0.14
# source_token_emb_145                0.14
# target_token_emb_137                0.14
# source_token_emb_4                  0.14
# source_type_B-Actor                 0.14
# source_token_emb_177                0.14
# source_token_emb_280                0.14
# target_token_emb_62                 0.14
# source_pos_tag_VBZ                  0.13
# source_token_emb_34                 0.13
# target_token_emb_144                0.13
# source_token_emb_78                 0.13
# source_token_emb_3                  0.13
# source_token_emb_250                0.13
# source_token_emb_182                0.13
# source_token_emb_69                 0.13
# target_token_emb_289                0.12
# target_token_emb_133                0.12
# source_token_emb_130                0.12
# source_type_B-Activity Data         0.12
# target_prev_tag_B-Actor             0.12
# target_token_emb_97                 0.12
# source_token_emb_224                0.12
# target_token_emb_283                0.12
# target_token_emb_43                 0.12
# source_token_emb_51                 0.12
# source_token_emb_228                0.12
# source_token_emb_152                0.12
# source_token_emb_151                0.11
# target_token_emb_19                 0.11
# target_token_emb_49                 0.11
# source_prev_tag_B-Actor             0.11
# target_token_emb_41                 0.11
# source_token_emb_101                0.11
# target_token_emb_107                0.11
# target_token_emb_58                 0.11
# source_token_emb_207                0.11
# target_token_emb_47                 0.11
# target_token_emb_269                0.11
# target_token_emb_44                 0.1
# target_token_emb_236                0.1
# target_token_emb_10                 0.1
# source_token_emb_16                 0.1
# source_token_emb_126                0.1
# target_token_emb_143                0.1
# target_token_emb_211                0.1
# source_prev_tag_B-XOR Gateway       0.1
# target_token_emb_205                0.1
# source_token_emb_36                 0.1
# source_token_emb_257                0.1
# target_token_emb_190                0.1
# source_token_emb_90                 0.1
# target_token_emb_20                 0.09
# target_token_emb_59                 0.09
# source_token_emb_56                 0.09
# source_token_emb_222                0.09
# source_token_emb_106                0.09
# target_token_emb_295                0.09
# source_token_emb_203                0.09
# source_token_emb_102                0.09
# source_token_emb_205                0.09
# source_token_emb_89                 0.09
# source_token_emb_296                0.09
# source_token_emb_244                0.09
# source_token_emb_74                 0.09
# target_token_emb_145                0.09
# target_token_emb_93                 0.09
# target_token_emb_85                 0.09
# source_token_emb_39                 0.09
# target_token_emb_197                0.09
# target_token_emb_31                 0.09
# target_token_emb_78                 0.08
# source_token_emb_232                0.08
# target_token_emb_237                0.08
# target_token_emb_286                0.08
# source_token_emb_35                 0.08
# source_token_emb_9                  0.08
# target_pos_tag_DT                   0.08
# source_token_emb_29                 0.08
# target_token_emb_221                0.08
# target_token_emb_232                0.08
# target_token_emb_16                 0.08
# source_token_emb_132                0.08
# target_token_emb_191                0.08
# source_token_emb_40                 0.08
# source_prev_tag_O                   0.08
# source_token_emb_72                 0.08
# source_token_emb_174                0.08
# target_token_emb_163                0.08
# target_token_emb_22                 0.07
# target_token_emb_220                0.07
# source_token_emb_5                  0.07
# target_token_emb_130                0.07
# source_token_emb_274                0.07
# target_token_emb_293                0.07
# target_token_emb_69                 0.07
# target_token_emb_275                0.07
# target_token_emb_30                 0.07
# source_token_emb_256                0.07
# target_token_emb_126                0.07
# target_token_emb_238                0.07
# target_token_emb_259                0.07
# target_token_emb_32                 0.07
# source_token_emb_201                0.07
# source_token_emb_73                 0.07
# target_token_emb_185                0.07
# target_token_emb_21                 0.07
# target_token_emb_260                0.07
# source_token_emb_215                0.07
# target_token_emb_6                  0.07
# target_token_emb_12                 0.07
# source_token_emb_276                0.07
# source_token_emb_50                 0.07
# target_pos_tag_VBN                  0.06
# target_token_emb_24                 0.06
# target_token_emb_146                0.06
# source_token_emb_290                0.06
# ...
# source_token_emb_37                 0.02
# target_token_emb_82                 0.02
# target_token_emb_106                0.02
# source_token_emb_10                 0.02
# source_pos_tag_NNP                  0.02
# source_token_emb_221                0.02
# target_token_emb_275                0.02
# target_token_emb_29                 0.02
# target_token_emb_261                0.02
# target_token_emb_238                0.02
# target_token_emb_266                0.02
# target_token_emb_281                0.02
# source_token_emb_16                 0.02
# target_token_emb_268                0.02
# source_token_emb_131                0.02
# source_token_emb_281                0.02
# target_token_emb_157                0.02
# target_pos_tag_PRP                  0.02
# target_token_emb_2                  0.02
# document_name_doc-9.1               0.02
# target_token_emb_86                 0.02
# target_token_emb_276                0.02
# source_token_emb_64                 0.02
# source_token_emb_282                0.02
# target_token_emb_136                0.02
# target_token_emb_134                0.02
# source_token_emb_213                0.02
# source_token_emb_256                0.02
# target_token_emb_61                 0.02
# source_token_emb_102                0.02
# source_token_emb_188                0.02
# target_token_emb_48                 0.02
# target_token_emb_240                0.02
# target_token_emb_231                0.02
# source_token_emb_206                0.02
# source_token_emb_179                0.02
# target_token_emb_56                 0.02
# target_token_emb_243                0.02
# source_token_emb_68                 0.02
# target_token_emb_219                0.02
# source_token_emb_299                0.02
# target_token_emb_200                0.02
# target_token_emb_11                 0.02
# document_name_doc-20.13 - thesis writing 0.02
# source_token_emb_127                0.02
# source_token_emb_194                0.02
# target_token_emb_26                 0.02
# target_token_emb_283                0.02
# target_token_emb_90                 0.02
# source_token_emb_246                0.02
# source_token_emb_96                 0.02
# target_token_emb_148                0.02
# target_token_emb_77                 0.02
# target_token_emb_208                0.02
# source_token_emb_149                0.02
# source_token_emb_228                0.02
# source_token_emb_50                 0.02
# target_token_emb_22                 0.02
# source_token_emb_187                0.02
# target_token_emb_145                0.02
# source_token_emb_124                0.01
# target_token_emb_196                0.01
# target_token_emb_213                0.01
# target_token_emb_93                 0.01
# source_token_emb_283                0.01
# source_token_emb_237                0.01
# source_token_emb_204                0.01
# target_prev_tag_B-Condition Specification 0.01
# source_token_emb_89                 0.01
# document_name_doc-5.1               0.01
# target_token_emb_274                0.01
# target_token_emb_126                0.01
# source_token_emb_202                0.01
# document_name_doc-20.2 - employee project approval 0.01
# target_token_emb_250                0.01
# target_token_emb_1                  0.01
# source_token_emb_24                 0.01
# source_token_emb_211                0.01
# source_token_emb_7                  0.01
# target_token_emb_147                0.01
# target_token_emb_162                0.01
# target_token_emb_220                0.01
# source_token_emb_161                0.01
# source_token_emb_75                 0.01
# target_token_emb_33                 0.01
# source_token_emb_11                 0.01
# source_token_emb_257                0.01
# source_token_emb_18                 0.01
# source_token_emb_60                 0.01
# target_token_emb_296                0.01
# source_token_emb_61                 0.01
# document_name_doc-20.12 - horse riding lesson 0.01
# source_token_emb_275                0.01
# target_token_emb_159                0.01
# source_token_emb_79                 0.01
# target_token_emb_181                0.01
# source_token_emb_171                0.01
# target_token_emb_70                 0.01
# target_token_emb_149                0.01
# target_token_emb_60                 0.01
# document_name_doc-20.10 - ISP student 0.01
# target_token_emb_224                0.01
# target_token_emb_51                 0.01
# target_token_emb_73                 0.01
# source_token_emb_183                0.01
# target_token_emb_265                0.01
# target_token_emb_65                 0.01
# source_token_emb_54                 0.01
# source_token_emb_157                0.01
# target_token_emb_167                0.01
# target_pos_tag_NN                   0.01
# source_token_emb_139                0.01
# target_token_emb_16                 0.01
# source_token_emb_150                0.01
# source_token_emb_272                0.01
# target_token_emb_233                0.01
# source_token_emb_164                0.01
# target_token_emb_76                 0.01
# source_token_emb_261                0.01
# target_token_emb_299                0.01
# target_token_emb_8                  0.01
# target_token_emb_164                0.01
# target_token_emb_260                0.01
# document_name_doc-10.14             0.01
# target_type_B-Condition Specification 0.01
# document_name_doc-2.1               0.01
# target_token_emb_107                0.01
# source_token_emb_120                0.01
# source_token_emb_231                0.01
# source_token_emb_3                  0.01
# source_token_emb_173                0.01
# source_token_emb_207                0.01
# document_name_doc-1.3               0.01
# target_prev_tag_B-Further Specification 0.01
# target_token_emb_229                0.01
# source_token_emb_8                  0.01
# target_token_emb_122                0.01
# source_token_emb_260                0.01
# target_token_emb_109                0.01
# source_token_emb_140                0.01
# target_prev_tag_B-Activity Data     0.01
# source_token_emb_248                0.01
# source_token_emb_247                0.01
# source_token_emb_163                0.01
# source_prev_tag_B-Further Specification 0.01
# source_token_emb_160                0.01
# target_token_emb_123                0.01
# document_name_doc-3.2               0.01
# document_name_doc-8.2               0.01
# target_token_emb_252                0.01
# target_token_emb_277                0.01
# target_token_emb_254                0.01
# document_name_doc-20.8 - order shipping 0.01
# source_token_emb_145                0.01
# target_token_emb_131                0.01
# target_token_emb_21                 0.01
# source_token_emb_32                 0.0
# source_token_emb_154                0.0
# target_token_emb_55                 0.0
# document_name_doc-20.11 - credit risk assessment 0.0
# source_token_emb_137                0.0
# target_token_emb_173                0.0
# source_token_emb_147                0.0
# target_token_emb_37                 0.0
# target_token_emb_38                 0.0
# source_token_emb_57                 0.0
# source_token_emb_76                 0.0
# target_token_emb_84                 0.0
# target_token_emb_43                 0.0
# document_name_doc-8.1               0.0
# source_token_emb_67                 0.0
# source_token_emb_97                 0.0
# source_token_emb_250                0.0
# source_token_emb_199                0.0
# target_token_emb_5                  0.0
# source_pos_tag_VBP                  0.0
# source_token_emb_226                0.0
# target_token_emb_257                0.0
# source_token_emb_178                0.0
# source_token_emb_48                 0.0
# target_token_emb_228                0.0
# target_token_emb_0                  0.0
# document_name_doc-3.5               0.0
# source_token_emb_212                0.0
# source_token_emb_215                0.0
# source_token_emb_98                 0.0
# source_token_emb_94                 0.0
# source_token_emb_277                0.0
# source_pos_tag_MD                   0.0
# source_pos_tag_NNS                  0.0
# document_name_doc-6.3               0.0
# source_token_emb_108                0.0
# document_name_doc-20.4 - procurement process 0.0
# target_pos_tag_VBG                  0.0
# target_token_emb_67                 0.0
# source_token_emb_29                 0.0
# source_token_emb_106                0.0
# target_token_emb_291                0.0
# target_token_emb_263                0.0
# document_name_doc-5.4               0.0
# document_name_doc-6.4               0.0
# source_token_emb_43                 0.0
# target_token_emb_111                0.0
# document_name_doc-9.2               0.0
# target_token_emb_199                0.0
# source_token_emb_118                0.0
# target_token_emb_125                0.0
# target_token_emb_262                0.0
# source_token_emb_287                0.0
# source_pos_tag_WRB                  0.0
# source_token_emb_153                0.0
# target_token_emb_225                0.0
# source_token_emb_100                0.0
# target_token_emb_57                 0.0
# target_token_emb_144                0.0
# target_next_tag_B-XOR Gateway       0.0
# source_token_emb_217                0.0
# target_token_emb_151                0.0
# target_token_emb_259                0.0
# target_token_emb_7                  0.0
# target_token_emb_269                0.0
# target_token_emb_292                0.0
# target_token_emb_195                0.0
# document_name_doc-4.1               0.0
# target_token_emb_24                 0.0
# source_token_emb_39                 0.0
# source_token_emb_56                 0.0
# source_token_emb_104                0.0
# source_token_emb_195                0.0
# dependency_tags_[2, 14]             0.0
# source_token_emb_116                0.0
# target_token_emb_202                0.0
# target_token_emb_211                0.0
# source_token_emb_103                0.0
# document_name_doc-20.14 - HR interview 0.0
# dependency_tags_[61, 41]            0.0
# document_name_doc-8.3               0.0
# target_token_emb_222                0.0
# source_token_emb_129                0.0
# document_name_doc-9.3               0.0
# source_token_emb_20                 0.0
# target_token_emb_124                0.0
# target_token_emb_191                0.0
# source_token_emb_81                 0.0
# target_token_emb_197                0.0
# target_pos_tag_MD                   0.0
# source_token_emb_289                0.0
# dependency_tags_[55, 50, 61, 4]     0.0
# target_token_emb_289                0.0
# document_name_doc-10.12             0.0
# document_name_doc-10.1              0.0
# document_name_doc-20.15 - library request 0.0
# target_token_emb_214                0.0
# source_token_emb_4                  0.0
# source_token_emb_255                0.0
# target_token_emb_270                0.0
# target_token_emb_160                0.0
# dependency_tags_[22, 1, 62]         0.0
# source_token_emb_233                0.0
# target_pos_tag_PDT                  0.0
# dependency_tags_[42, 61, 14]        0.0
# dependency_tags_[55, 60, 50, 61]    0.0
# target_token_emb_94                 0.0
# dependency_tags_[55, 61, 41]        0.0
# dependency_tags_[55, 61]            0.0
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9878
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7786
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.9878
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7302
# actor recipient                     0.8125
# flow                                0.5015
# further specification               0.8889
# no_relation                         0.994
# same gateway                        0.5806
# uses                                0.9426
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# ------------------------
#
# Aggregated metrics fold 5
#
# Micro F1        Macro F1        Weighted F1
# 0.9876          0.7786          0.9878
#
# ------------------------
# ------------------------
#
# Crossvalidation finished
#
# Best fold 1
#
# ------------------------
# ------------------------
#
# Average F1 across all folds:
#
# Micro F1        Macro F1        Weighted F1
# 0.9880          0.7807          0.9881
#
# ------------------------
# ------------------------
# AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS
#
# Label                               Precision       Recall          F1
#
# actor performer                     0.7587          0.7122          0.7347
# actor recipient                     0.8828          0.8245          0.8524
# flow                                0.4879          0.5215          0.504
# further specification               0.8637          0.8889          0.8746
# no_relation                         0.9944          0.9939          0.9941
# same gateway                        0.5438          0.5867          0.5598
# uses                                0.9224          0.97            0.9456
#
# ------------------------
# ------------------------
# CLASS WEIGHTS USED

# %% [markdown]
# ###6.3.2. SMOTE on baseline data
#
# Crossvalidation was done using the baseline data that is enriched using SMOTE for the 'flow' relation only.

# %%
best_model_SMOTE = crossvalidation_SMOTE(input_data_smote, "ignore", SEED, test_size, folds, use_class_weights=True)
# Save the best model to a file
model_path = "/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TRAINED_CATBOOST_MODEL/best_catboost_model_using_SMOTE.cbm"
best_model_SMOTE.save_model(model_path, format="cbm")
# Out:
# <ipython-input-10-1205813b8751>:22: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]
# ---------------------------------------
#
# Training fold 1...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   18.9
# source_type_B-Activity              6.36
# token_distance                      4.9
# target_type_B-Actor                 4.67
# target_type_B-Activity              2.31
# target_sentence_ID                  2.3
# source_token_ID                     2.21
# target_token_ID                     1.89
# source_sentence_ID                  1.6
# source_pos_tag_IN                   1.34
# target_type_B-Activity Data         1.24
# target_pos_tag_IN                   1.18
# target_type_B-XOR Gateway           1.15
# target_token_emb_276                0.84
# source_next_tag_B-Condition Specification 0.84
# target_prev_tag_O                   0.71
# source_type_B-XOR Gateway           0.69
# target_token_emb_71                 0.67
# source_prev_tag_O                   0.6
# target_next_tag_O                   0.58
# source_next_tag_O                   0.55
# source_token_emb_276                0.55
# target_token_emb_101                0.53
# source_token_emb_135                0.52
# target_token_emb_239                0.5
# target_token_emb_293                0.48
# target_token_emb_149                0.47
# source_type_B-Condition Specification 0.47
# target_next_tag_B-Activity          0.43
# target_token_emb_46                 0.42
# source_token_emb_90                 0.42
# target_token_emb_253                0.42
# target_token_emb_132                0.41
# target_token_emb_258                0.39
# source_token_emb_46                 0.39
# source_token_emb_167                0.38
# source_token_emb_97                 0.38
# source_token_emb_56                 0.36
# target_token_emb_50                 0.35
# target_token_emb_112                0.35
# source_token_emb_101                0.35
# target_token_emb_200                0.33
# source_token_emb_116                0.33
# target_token_emb_199                0.33
# target_token_emb_114                0.32
# source_token_emb_28                 0.31
# source_token_emb_189                0.31
# source_token_emb_156                0.3
# source_pos_tag_DT                   0.29
# source_token_emb_58                 0.29
# source_token_emb_80                 0.29
# source_token_emb_34                 0.28
# source_token_emb_25                 0.28
# target_token_emb_78                 0.27
# source_token_emb_283                0.27
# target_token_emb_244                0.26
# source_token_emb_72                 0.26
# source_token_emb_241                0.26
# source_token_emb_45                 0.26
# target_token_emb_96                 0.26
# target_token_emb_49                 0.26
# source_token_emb_114                0.26
# target_token_emb_109                0.26
# target_token_emb_9                  0.25
# source_pos_tag_VBN                  0.25
# source_token_emb_89                 0.25
# target_token_emb_282                0.25
# target_token_emb_3                  0.25
# source_token_emb_240                0.23
# target_token_emb_67                 0.23
# source_token_emb_235                0.21
# source_token_emb_9                  0.21
# source_token_emb_21                 0.21
# target_type_B-Further Specification 0.21
# source_token_emb_39                 0.21
# source_token_emb_204                0.2
# target_token_emb_270                0.2
# target_token_emb_278                0.2
# target_token_emb_191                0.2
# target_token_emb_248                0.2
# target_token_emb_235                0.2
# target_token_emb_146                0.2
# target_token_emb_27                 0.19
# source_token_emb_71                 0.19
# source_token_emb_149                0.19
# source_token_emb_62                 0.19
# source_token_emb_196                0.19
# target_token_emb_206                0.18
# source_token_emb_102                0.18
# source_token_emb_130                0.18
# target_token_emb_110                0.18
# target_token_emb_40                 0.18
# target_token_emb_211                0.17
# target_token_emb_223                0.17
# source_token_emb_162                0.17
# source_token_emb_65                 0.17
# target_token_emb_179                0.17
# source_token_emb_59                 0.17
# target_token_emb_257                0.17
# source_token_emb_174                0.17
# target_token_emb_220                0.17
# target_token_emb_262                0.16
# source_token_emb_290                0.16
# target_token_emb_288                0.16
# source_token_emb_262                0.16
# target_token_emb_31                 0.15
# source_token_emb_125                0.15
# target_next_tag_B-Condition Specification 0.15
# target_token_emb_6                  0.15
# target_type_B-Condition Specification 0.15
# source_token_emb_84                 0.15
# source_token_emb_265                0.15
# source_token_emb_177                0.15
# target_token_emb_135                0.15
# source_token_emb_282                0.14
# target_token_emb_158                0.14
# source_token_emb_91                 0.14
# source_token_emb_226                0.14
# target_token_emb_69                 0.14
# source_token_emb_67                 0.14
# source_token_emb_247                0.14
# target_pos_tag_RB                   0.14
# source_token_emb_186                0.13
# target_token_emb_215                0.13
# source_token_emb_134                0.13
# target_token_emb_174                0.13
# source_pos_tag_RB                   0.13
# target_token_emb_89                 0.13
# target_prev_tag_B-Actor             0.13
# source_token_emb_244                0.13
# source_token_emb_120                0.13
# target_token_emb_251                0.13
# source_token_emb_6                  0.13
# source_token_emb_209                0.12
# target_token_emb_58                 0.12
# target_token_emb_281                0.12
# source_token_emb_179                0.12
# source_token_emb_222                0.12
# target_token_emb_64                 0.12
# target_token_emb_145                0.12
# target_token_emb_224                0.12
# target_token_emb_139                0.12
# source_token_emb_184                0.11
# source_token_emb_66                 0.11
# source_token_emb_17                 0.11
# target_token_emb_273                0.11
# target_token_emb_192                0.11
# target_token_emb_194                0.11
# source_token_emb_245                0.11
# source_token_emb_148                0.11
# target_token_emb_84                 0.11
# source_token_emb_201                0.11
# target_token_emb_266                0.11
# source_token_emb_133                0.11
# source_token_emb_40                 0.11
# target_token_emb_19                 0.11
# source_token_emb_264                0.1
# target_token_emb_210                0.1
# source_token_emb_73                 0.1
# target_token_emb_98                 0.1
# source_token_emb_220                0.1
# source_token_emb_193                0.1
# target_token_emb_42                 0.1
# source_prev_tag_B-XOR Gateway       0.1
# source_token_emb_42                 0.1
# source_token_emb_228                0.1
# target_token_emb_203                0.1
# source_token_emb_24                 0.1
# source_token_emb_115                0.1
# target_token_emb_173                0.09
# source_token_emb_195                0.09
# source_token_emb_11                 0.09
# target_token_emb_47                 0.09
# source_prev_tag_B-Actor             0.09
# source_token_emb_298                0.09
# source_token_emb_286                0.09
# target_token_emb_12                 0.09
# source_token_emb_197                0.09
# target_token_emb_268                0.09
# source_token_emb_16                 0.09
# target_token_emb_99                 0.09
# target_token_emb_83                 0.09
# source_token_emb_78                 0.09
# target_token_emb_73                 0.09
# target_token_emb_55                 0.09
# source_token_emb_26                 0.09
# source_token_emb_123                0.08
# source_token_emb_270                0.08
# source_token_emb_4                  0.08
# target_token_emb_142                0.08
# target_token_emb_225                0.08
# target_token_emb_166                0.08
# source_token_emb_248                0.08
# target_token_emb_229                0.08
# target_token_emb_204                0.08
# source_token_emb_216                0.08
# target_token_emb_129                0.08
# target_token_emb_79                 0.08
# source_token_emb_137                0.08
# target_token_emb_150                0.08
# source_token_emb_147                0.08
# source_token_emb_295                0.08
# target_token_emb_134                0.08
# target_token_emb_289                0.08
# target_next_tag_B-Actor             0.08
# target_token_emb_216                0.08
# source_token_emb_0                  0.08
# target_token_emb_20                 0.08
# target_token_emb_269                0.08
# source_token_emb_150                0.08
# source_token_emb_221                0.07
# source_token_emb_124                0.07
# target_token_emb_155                0.07
# source_token_emb_289                0.07
# target_token_emb_277                0.07
# source_token_emb_74                 0.07
# source_next_tag_B-Actor             0.07
# target_token_emb_86                 0.07
# source_token_emb_285                0.07
# target_token_emb_102                0.07
# source_token_emb_64                 0.07
# target_token_emb_124                0.07
# target_token_emb_76                 0.07
# source_token_emb_252                0.07
# target_token_emb_154                0.07
# target_token_emb_85                 0.07
# source_token_emb_254                0.07
# target_token_emb_95                 0.07
# source_token_emb_180                0.07
# source_token_emb_87                 0.07
# target_token_emb_232                0.07
# source_token_emb_31                 0.07
# source_token_emb_284                0.07
# source_token_emb_232                0.06
# target_token_emb_209                0.06
# source_token_emb_218                0.06
# source_token_emb_20                 0.06
# source_token_emb_12                 0.06
# source_token_emb_223                0.06
# source_token_emb_33                 0.06
# source_token_emb_100                0.06
# source_token_emb_110                0.06
# target_token_emb_51                 0.06
# source_token_emb_50                 0.06
# source_token_emb_126                0.06
# source_token_emb_292                0.06
# document_name_doc-4.1               0.06
# target_token_emb_227                0.06
# source_token_emb_299                0.06
# source_token_emb_160                0.06
# source_token_emb_18                 0.06
# source_token_emb_152                0.06
# source_token_emb_297                0.06
# source_token_emb_47                 0.06
# source_token_emb_117                0.06
# source_token_emb_272                0.06
# target_token_emb_36                 0.06
# source_token_emb_104                0.05
# target_prev_tag_NONE                0.05
# source_token_emb_182                0.05
# source_token_emb_95                 0.05
# target_token_emb_171                0.05
# target_token_emb_122                0.05
# source_token_emb_178                0.05
# source_token_emb_236                0.05
# source_token_emb_151                0.05
# source_pos_tag_NNP                  0.05
# source_next_tag_B-Activity Data     0.05
# target_token_emb_283                0.05
# source_token_emb_5                  0.05
# source_token_emb_88                 0.05
# target_token_emb_91                 0.05
# target_token_emb_238                0.05
# source_token_emb_274                0.05
# source_token_emb_239                0.05
# source_token_emb_129                0.05
# source_token_emb_54                 0.05
# source_token_emb_176                0.05
# source_token_emb_140                0.05
# source_token_emb_217                0.05
# source_token_emb_231                0.05
# target_token_emb_13                 0.05
# source_token_emb_280                0.05
# source_token_emb_227                0.05
# source_type_B-Activity Data         0.05
# target_token_emb_108                0.05
# source_type_B-Actor                 0.05
# source_token_emb_181                0.05
# target_token_emb_60                 0.05
# source_token_emb_92                 0.05
# source_token_emb_15                 0.05
# target_token_emb_90                 0.05
# target_token_emb_82                 0.04
# target_token_emb_143                0.04
# target_token_emb_94                 0.04
# source_token_emb_251                0.04
# source_token_emb_266                0.04
# target_token_emb_34                 0.04
# target_token_emb_285                0.04
# source_token_emb_49                 0.04
# target_token_emb_214                0.04
# target_token_emb_119                0.04
# target_token_emb_87                 0.04
# source_token_emb_145                0.04
# source_token_emb_81                 0.04
# source_token_emb_8                  0.04
# source_token_emb_288                0.04
# source_token_emb_198                0.04
# source_token_emb_229                0.04
# source_token_emb_83                 0.04
# source_token_emb_293                0.04
# target_token_emb_264                0.04
# target_token_emb_186                0.04
# source_token_emb_27                 0.04
# source_token_emb_281                0.04
# source_pos_tag_VBZ                  0.04
# target_token_emb_138                0.04
# target_pos_tag_VBZ                  0.04
# target_token_emb_172                0.04
# source_token_emb_206                0.04
# source_token_emb_194                0.04
# target_token_emb_66                 0.04
# source_token_emb_55                 0.04
# target_pos_tag_WRB                  0.04
# target_token_emb_153                0.04
# target_token_emb_241                0.03
# target_token_emb_287                0.03
# target_token_emb_256                0.03
# source_token_emb_207                0.03
# source_token_emb_103                0.03
# source_token_emb_163                0.03
# target_token_emb_185                0.03
# source_token_emb_219                0.03
# target_token_emb_178                0.03
# target_token_emb_38                 0.03
# target_token_emb_92                 0.03
# target_token_emb_136                0.03
# document_name_doc-9.2               0.03
# target_pos_tag_VBN                  0.03
# source_token_emb_269                0.03
# target_token_emb_197                0.03
# target_token_emb_274                0.03
# document_name_doc-1.2               0.03
# target_token_emb_131                0.03
# target_pos_tag_DT                   0.03
# source_token_emb_261                0.03
# target_pos_tag_VB                   0.03
# source_token_emb_105                0.03
# target_token_emb_53                 0.03
# source_token_emb_77                 0.03
# target_token_emb_157                0.03
# source_token_emb_118                0.03
# document_name_doc-10.2              0.03
# source_token_emb_131                0.03
# target_token_emb_14                 0.03
# target_token_emb_189                0.03
# target_token_emb_24                 0.03
# source_token_emb_246                0.03
# source_token_emb_132                0.03
# target_token_emb_263                0.03
# source_token_emb_279                0.03
# source_token_emb_260                0.03
# target_token_emb_286                0.03
# target_token_emb_106                0.03
# source_token_emb_224                0.03
# source_token_emb_60                 0.03
# source_token_emb_3                  0.03
# source_token_emb_166                0.03
# target_token_emb_161                0.03
# source_token_emb_96                 0.03
# target_token_emb_233                0.03
# document_name_doc-20.13 - thesis writing 0.03
# source_token_emb_185                0.03
# target_token_emb_250                0.03
# source_token_emb_128                0.03
# source_token_emb_199                0.02
# target_token_emb_5                  0.02
# target_token_emb_97                 0.02
# source_token_emb_111                0.02
# target_token_emb_22                 0.02
# target_pos_tag_NNP                  0.02
# source_token_emb_188                0.02
# target_token_emb_48                 0.02
# source_token_emb_294                0.02
# source_token_emb_10                 0.02
# target_pos_tag_VBG                  0.02
# source_token_emb_215                0.02
# source_token_emb_173                0.02
# target_token_emb_198                0.02
# target_token_emb_295                0.02
# source_token_emb_86                 0.02
# target_token_emb_72                 0.02
# source_token_emb_212                0.02
# target_token_emb_26                 0.02
# target_token_emb_65                 0.02
# target_token_emb_77                 0.02
# target_token_emb_208                0.02
# source_token_emb_158                0.02
# source_token_emb_70                 0.02
# source_token_emb_159                0.02
# target_token_emb_121                0.02
# source_token_emb_136                0.02
# target_token_emb_217                0.02
# target_token_emb_61                 0.02
# target_token_emb_54                 0.02
# target_token_emb_187                0.02
# target_token_emb_252                0.02
# target_token_emb_17                 0.02
# target_token_emb_21                 0.02
# target_token_emb_296                0.02
# target_token_emb_151                0.02
# source_token_emb_253                0.02
# target_next_tag_B-Activity Data     0.02
# target_token_emb_175                0.02
# target_token_emb_116                0.02
# source_token_emb_127                0.02
# target_prev_tag_B-XOR Gateway       0.02
# target_token_emb_137                0.02
# target_token_emb_182                0.02
# target_token_emb_88                 0.02
# source_token_emb_208                0.02
# target_token_emb_218                0.02
# target_token_emb_180                0.02
# target_token_emb_68                 0.02
# source_token_emb_214                0.02
# source_token_emb_51                 0.02
# source_token_emb_29                 0.02
# target_token_emb_228                0.02
# source_token_emb_287                0.02
# target_token_emb_201                0.02
# target_token_emb_254                0.02
# target_token_emb_183                0.02
# target_token_emb_236                0.02
# source_token_emb_275                0.02
# target_token_emb_152                0.02
# target_token_emb_163                0.02
# target_token_emb_2                  0.02
# target_token_emb_127                0.02
# source_token_emb_237                0.02
# target_token_emb_74                 0.02
# target_token_emb_113                0.02
# document_name_doc-5.3               0.02
# target_token_emb_193                0.02
# target_token_emb_15                 0.02
# source_token_emb_93                 0.02
# source_token_emb_146                0.01
# target_token_emb_115                0.01
# source_token_emb_191                0.01
# source_token_emb_57                 0.01
# source_token_emb_107                0.01
# target_token_emb_29                 0.01
# document_name_doc-20.5 - edit pictures 0.01
# source_token_emb_296                0.01
# source_token_emb_171                0.01
# target_token_emb_237                0.01
# target_token_emb_205                0.01
# target_token_emb_222                0.01
# source_token_emb_200                0.01
# source_token_emb_255                0.01
# target_token_emb_260                0.01
# target_token_emb_59                 0.01
# source_token_emb_213                0.01
# document_name_doc-5.1               0.01
# target_token_emb_70                 0.01
# target_token_emb_164                0.01
# source_token_emb_41                 0.01
# target_token_emb_118                0.01
# source_token_emb_153                0.01
# source_token_emb_249                0.01
# target_token_emb_297                0.01
# source_token_emb_277                0.01
# document_name_doc-2.2               0.01
# source_token_emb_168                0.01
# source_token_emb_234                0.01
# target_token_emb_33                 0.01
# source_token_emb_154                0.01
# source_token_emb_161                0.01
# target_token_emb_170                0.01
# source_token_emb_53                 0.01
# source_token_emb_2                  0.01
# target_token_emb_212                0.01
# target_token_emb_167                0.01
# source_next_tag_B-Further Specification 0.01
# source_token_emb_256                0.01
# target_prev_tag_B-Activity          0.01
# source_token_emb_267                0.01
# source_token_emb_32                 0.01
# target_token_emb_4                  0.01
# source_token_emb_75                 0.01
# target_token_emb_271                0.01
# target_token_emb_259                0.01
# source_token_emb_122                0.01
# target_token_emb_45                 0.01
# source_pos_tag_VB                   0.01
# target_token_emb_267                0.01
# source_token_emb_19                 0.01
# target_token_emb_294                0.01
# source_token_emb_271                0.01
# target_token_emb_8                  0.01
# source_pos_tag_VBG                  0.01
# target_token_emb_117                0.01
# target_pos_tag_VBP                  0.01
# target_token_emb_162                0.01
# source_token_emb_48                 0.01
# target_token_emb_188                0.01
# source_token_emb_38                 0.01
# target_token_emb_242                0.01
# source_token_emb_183                0.01
# document_name_doc-20.2 - employee project approval 0.01
# target_token_emb_213                0.01
# source_token_emb_109                0.01
# target_token_emb_100                0.01
# source_token_emb_263                0.01
# target_token_emb_195                0.01
# target_token_emb_56                 0.01
# target_token_emb_52                 0.01
# source_token_emb_121                0.01
# target_token_emb_93                 0.01
# document_name_doc-6.3               0.01
# target_token_emb_120                0.01
# target_prev_tag_B-Further Specification 0.01
# source_token_emb_113                0.01
# source_token_emb_35                 0.01
# source_token_emb_225                0.01
# source_prev_tag_B-Further Specification 0.01
# source_token_emb_250                0.01
# target_token_emb_181                0.01
# target_token_emb_80                 0.01
# source_token_emb_187                0.01
# source_pos_tag_JJ                   0.01
# target_token_emb_246                0.01
# source_token_emb_278                0.01
# source_token_emb_98                 0.01
# source_token_emb_23                 0.01
# source_token_emb_258                0.01
# target_token_emb_32                 0.01
# target_token_emb_202                0.01
# source_token_emb_112                0.01
# source_pos_tag_VBP                  0.01
# source_token_emb_143                0.01
# target_token_emb_57                 0.01
# target_token_emb_219                0.01
# target_pos_tag_PRP                  0.01
# document_name_doc-20.10 - ISP student 0.01
# document_name_doc-9.1               0.01
# target_token_emb_41                 0.01
# target_token_emb_105                0.01
# source_token_emb_164                0.01
# document_name_doc-10.3              0.01
# source_token_emb_205                0.01
# target_token_emb_292                0.01
# source_token_emb_85                 0.01
# source_token_emb_268                0.01
# target_token_emb_272                0.01
# source_token_emb_210                0.01
# source_token_emb_79                 0.01
# source_token_emb_69                 0.01
# target_token_emb_23                 0.0
# source_token_emb_14                 0.0
# target_token_emb_221                0.0
# source_token_emb_230                0.0
# target_token_emb_28                 0.0
# source_token_emb_36                 0.0
# target_token_emb_81                 0.0
# document_name_doc-8.2               0.0
# target_token_emb_290                0.0
# target_token_emb_177                0.0
# target_token_emb_196                0.0
# source_token_emb_238                0.0
# source_token_emb_211                0.0
# target_prev_tag_B-Activity Data     0.0
# source_token_emb_192                0.0
# target_token_emb_104                0.0
# target_token_emb_63                 0.0
# source_token_emb_108                0.0
# source_token_emb_99                 0.0
# target_token_emb_123                0.0
# source_token_emb_170                0.0
# source_token_emb_52                 0.0
# target_token_emb_16                 0.0
# source_token_emb_68                 0.0
# source_token_emb_13                 0.0
# document_name_doc-5.4               0.0
# dependency_tags_[2, 61]             0.0
# document_name_doc-20.15 - library request 0.0
# source_token_emb_259                0.0
# dependency_tags_[55, 61]            0.0
# source_token_emb_139                0.0
# target_token_emb_160                0.0
# source_pos_tag_VBD                  0.0
# target_token_emb_234                0.0
# target_token_emb_1                  0.0
# document_name_doc-20.3 - project manager approval 0.0
# target_token_emb_126                0.0
# target_token_emb_125                0.0
# source_token_emb_82                 0.0
# source_token_emb_106                0.0
# source_token_emb_257                0.0
# source_token_emb_142                0.0
# document_name_doc-3.2               0.0
# target_token_emb_298                0.0
# source_token_emb_202                0.0
# target_token_emb_279                0.0
# source_token_emb_157                0.0
# target_token_emb_148                0.0
# target_token_emb_10                 0.0
# target_token_emb_226                0.0
# document_name_doc-3.3               0.0
# target_token_emb_176                0.0
# document_name_doc-8.1               0.0
# document_name_doc-3.1               0.0
# document_name_doc-3.5               0.0
# target_token_emb_128                0.0
# target_token_emb_247                0.0
# target_token_emb_103                0.0
# source_pos_tag_NNS                  0.0
# target_token_emb_130                0.0
# target_token_emb_280                0.0
# target_token_emb_231                0.0
# target_token_emb_156                0.0
# document_name_doc-9.5               0.0
# source_pos_tag_MD                   0.0
# document_name_doc-20.11 - credit risk assessment 0.0
# source_token_emb_155                0.0
# target_token_emb_249                0.0
# document_name_doc-8.3               0.0
# target_prev_tag_B-Condition Specification 0.0
# source_token_emb_291                0.0
# target_token_emb_39                 0.0
# document_name_doc-20.4 - procurement process 0.0
# target_token_emb_275                0.0
# document_name_doc-3.6               0.0
# document_name_doc-1.3               0.0
# target_token_emb_133                0.0
# source_token_emb_172                0.0
# source_pos_tag_WRB                  0.0
# target_pos_tag_TO                   0.0
# document_name_doc-20.14 - HR interview 0.0
# target_token_emb_11                 0.0
# target_token_emb_35                 0.0
# dependency_tags_[2, 14, 61]         0.0
# source_token_emb_44                 0.0
# source_token_emb_7                  0.0
# target_token_emb_144                0.0
# target_token_emb_265                0.0
# source_token_emb_233                0.0
# source_token_emb_43                 0.0
# source_token_emb_144                0.0
# source_token_emb_175                0.0
# source_token_emb_63                 0.0
# source_token_emb_76                 0.0
# source_token_emb_203                0.0
# dependency_tags_[55, 50, 61, 4]     0.0
# dependency_tags_[11, 61]            0.0
# document_name_doc-1.4               0.0
# target_token_emb_75                 0.0
# target_token_emb_18                 0.0
# document_name_doc-7.1               0.0
# target_token_emb_25                 0.0
# target_token_emb_147                0.0
# source_token_emb_37                 0.0
# target_pos_tag_CD                   0.0
# dependency_tags_[61, 41]            0.0
# target_pos_tag_UH                   0.0
# target_token_emb_207                0.0
# dependency_tags_[55, 2]             0.0
# dependency_tags_[55, 61, 41]        0.0
# target_pos_tag_MD                   0.0
# dependency_tags_[42, 61, 14]        0.0
# dependency_tags_[22, 1, 62]         0.0
# dependency_tags_[55, 50, 1, 61]     0.0
# target_token_emb_30                 0.0
# document_name_doc-20.9 - complaint process model 0.0
# source_pos_tag_CD                   0.0
# dependency_tags_[55, 50, 1]         0.0
# dependency_tags_[55, 50, 14]        0.0
# dependency_tags_[61, 14]            0.0
# source_token_emb_30                 0.0
# dependency_tags_[55, 11]            0.0
# dependency_tags_[2, 14]             0.0
# dependency_tags_[2, 62]             0.0
# dependency_tags_[2, 61, 14]         0.0
# dependency_tags_[22, 14]            0.0
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9896
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7923
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.9896
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7778
# actor recipient                     0.8667
# flow                                0.5156
# further specification               0.8571
# no_relation                         0.9953
# same gateway                        0.5833
# uses                                0.95
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# ------------------------
#
# Aggregated metrics fold 1
#
# Micro F1        Macro F1        Weighted F1
# 0.9905          0.7923          0.9896
#
# ---------------------------------------
#
# Training fold 2...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   19.16
# source_type_B-Activity              6.12
# token_distance                      5.3
# target_type_B-Actor                 5.27
# source_type_B-XOR Gateway           2.29
# target_token_ID                     2.28
# target_sentence_ID                  2.28
# target_type_B-Activity Data         2.16
# target_type_B-Activity              2.02
# target_type_B-XOR Gateway           1.84
# source_sentence_ID                  1.81
# target_token_emb_199                1.24
# source_token_ID                     0.87
# target_pos_tag_IN                   0.78
# target_token_emb_174                0.73
# source_next_tag_B-Condition Specification 0.65
# source_token_emb_191                0.65
# source_pos_tag_DT                   0.6
# target_token_emb_189                0.52
# source_token_emb_114                0.5
# source_token_emb_3                  0.49
# source_token_emb_62                 0.45
# target_token_emb_259                0.43
# source_type_B-Condition Specification 0.43
# source_token_emb_174                0.41
# source_token_emb_34                 0.41
# target_token_emb_23                 0.4
# target_token_emb_62                 0.4
# target_token_emb_265                0.38
# target_token_emb_182                0.37
# source_token_emb_141                0.36
# target_token_emb_63                 0.35
# source_pos_tag_IN                   0.35
# source_token_emb_57                 0.35
# target_token_emb_21                 0.34
# source_token_emb_45                 0.33
# target_token_emb_22                 0.33
# source_token_emb_181                0.33
# target_token_emb_53                 0.32
# source_token_emb_281                0.32
# target_token_emb_109                0.31
# target_token_emb_230                0.29
# target_next_tag_B-Condition Specification 0.29
# target_token_emb_89                 0.29
# source_token_emb_154                0.28
# target_token_emb_44                 0.28
# target_token_emb_36                 0.27
# source_token_emb_172                0.27
# target_next_tag_B-Activity Data     0.27
# source_token_emb_101                0.27
# target_token_emb_65                 0.27
# source_token_emb_9                  0.26
# source_token_emb_156                0.26
# target_type_B-Further Specification 0.26
# target_token_emb_101                0.25
# target_token_emb_183                0.25
# source_pos_tag_VBN                  0.24
# target_token_emb_9                  0.24
# source_token_emb_26                 0.24
# source_token_emb_239                0.24
# target_token_emb_130                0.24
# target_token_emb_244                0.23
# source_token_emb_46                 0.23
# source_token_emb_125                0.23
# target_token_emb_18                 0.23
# target_token_emb_105                0.23
# source_token_emb_41                 0.22
# target_token_emb_42                 0.22
# target_next_tag_B-Activity          0.22
# source_token_emb_22                 0.21
# target_token_emb_236                0.21
# target_token_emb_7                  0.21
# target_next_tag_O                   0.21
# source_token_emb_153                0.21
# source_token_emb_220                0.21
# source_token_emb_109                0.21
# target_token_emb_96                 0.21
# source_token_emb_149                0.2
# target_token_emb_85                 0.2
# target_token_emb_54                 0.19
# source_token_emb_285                0.19
# target_token_emb_254                0.19
# source_token_emb_200                0.19
# source_token_emb_188                0.18
# source_token_emb_265                0.18
# source_token_emb_53                 0.18
# source_token_emb_180                0.18
# target_prev_tag_O                   0.18
# target_token_emb_135                0.18
# source_token_emb_136                0.17
# source_token_emb_106                0.17
# target_token_emb_103                0.17
# target_token_emb_157                0.17
# target_token_emb_10                 0.17
# target_token_emb_156                0.17
# target_token_emb_16                 0.17
# target_token_emb_288                0.17
# target_token_emb_152                0.16
# source_token_emb_29                 0.16
# source_prev_tag_B-Actor             0.16
# target_token_emb_113                0.16
# source_token_emb_254                0.16
# target_token_emb_187                0.15
# target_token_emb_90                 0.15
# source_token_emb_241                0.15
# source_token_emb_280                0.15
# target_token_emb_240                0.15
# target_token_emb_136                0.15
# target_token_emb_117                0.14
# target_token_emb_94                 0.14
# target_prev_tag_B-Activity          0.14
# target_pos_tag_RB                   0.14
# source_token_emb_282                0.14
# source_token_emb_255                0.14
# target_token_emb_206                0.14
# target_token_emb_47                 0.14
# source_token_emb_251                0.13
# target_token_emb_193                0.13
# source_token_emb_32                 0.13
# target_token_emb_121                0.13
# target_token_emb_25                 0.13
# source_token_emb_80                 0.13
# source_token_emb_31                 0.13
# target_token_emb_229                0.13
# target_token_emb_277                0.13
# target_token_emb_276                0.13
# source_token_emb_43                 0.13
# source_token_emb_77                 0.13
# target_token_emb_293                0.13
# source_token_emb_65                 0.13
# target_token_emb_119                0.12
# target_token_emb_79                 0.12
# source_token_emb_212                0.12
# source_token_emb_84                 0.12
# target_token_emb_120                0.12
# target_token_emb_73                 0.12
# target_token_emb_67                 0.12
# source_pos_tag_RB                   0.12
# target_token_emb_203                0.12
# target_token_emb_6                  0.12
# target_token_emb_108                0.12
# source_token_emb_272                0.12
# target_token_emb_299                0.12
# target_token_emb_31                 0.11
# source_token_emb_63                 0.11
# source_token_emb_121                0.11
# source_token_emb_40                 0.11
# target_token_emb_84                 0.11
# target_token_emb_4                  0.11
# source_token_emb_222                0.11
# target_token_emb_181                0.11
# target_token_emb_242                0.11
# target_token_emb_88                 0.11
# target_token_emb_134                0.11
# target_token_emb_207                0.1
# target_token_emb_158                0.1
# source_token_emb_67                 0.1
# target_token_emb_205                0.1
# source_next_tag_O                   0.1
# target_token_emb_191                0.1
# target_token_emb_212                0.1
# target_token_emb_256                0.1
# source_token_emb_81                 0.1
# target_token_emb_258                0.1
# source_token_emb_148                0.1
# source_token_emb_196                0.1
# source_token_emb_60                 0.1
# target_token_emb_260                0.1
# target_token_emb_202                0.1
# target_token_emb_280                0.1
# target_token_emb_125                0.1
# source_token_emb_33                 0.1
# source_token_emb_108                0.1
# target_token_emb_41                 0.1
# source_token_emb_152                0.09
# target_token_emb_278                0.09
# source_token_emb_82                 0.09
# target_token_emb_188                0.09
# target_token_emb_142                0.09
# target_token_emb_81                 0.09
# source_token_emb_226                0.09
# source_token_emb_248                0.09
# source_token_emb_229                0.09
# target_token_emb_292                0.09
# target_token_emb_114                0.09
# source_token_emb_17                 0.09
# source_token_emb_25                 0.09
# source_token_emb_131                0.09
# target_token_emb_82                 0.09
# source_token_emb_91                 0.09
# target_token_emb_195                0.08
# target_token_emb_118                0.08
# source_token_emb_216                0.08
# target_token_emb_194                0.08
# target_pos_tag_VBN                  0.08
# target_token_emb_257                0.08
# target_token_emb_40                 0.08
# source_token_emb_185                0.08
# target_token_emb_145                0.08
# source_token_emb_238                0.08
# source_next_tag_B-Activity Data     0.08
# ...
# source_token_emb_219                0.02
# source_token_emb_115                0.02
# target_token_emb_25                 0.02
# target_token_emb_232                0.02
# target_token_emb_10                 0.02
# source_token_emb_295                0.02
# source_token_emb_178                0.02
# source_token_emb_105                0.02
# source_token_emb_234                0.02
# source_token_emb_259                0.02
# source_token_emb_25                 0.02
# source_token_emb_164                0.02
# source_token_emb_232                0.02
# target_pos_tag_VBG                  0.02
# source_token_emb_202                0.02
# source_token_emb_17                 0.02
# source_token_emb_229                0.02
# source_token_emb_33                 0.02
# target_token_emb_118                0.02
# source_token_emb_153                0.02
# source_token_emb_272                0.02
# document_name_doc-1.2               0.02
# source_token_emb_279                0.02
# source_token_emb_46                 0.02
# target_token_emb_128                0.02
# source_token_emb_262                0.02
# target_token_emb_209                0.02
# target_token_emb_151                0.02
# source_token_emb_6                  0.02
# target_token_emb_171                0.02
# source_token_emb_258                0.02
# target_token_emb_96                 0.02
# source_token_emb_71                 0.02
# document_name_doc-10.2              0.02
# target_token_emb_11                 0.02
# source_token_emb_210                0.02
# source_token_emb_217                0.02
# document_name_doc-20.13 - thesis writing 0.02
# source_token_emb_49                 0.02
# source_token_emb_184                0.02
# source_token_emb_67                 0.02
# target_token_emb_227                0.02
# target_token_emb_126                0.02
# source_token_emb_66                 0.02
# source_token_emb_246                0.02
# target_pos_tag_VBZ                  0.02
# target_token_emb_185                0.02
# target_token_emb_95                 0.02
# target_token_emb_246                0.02
# document_name_doc-20.2 - employee project approval 0.02
# target_token_emb_138                0.02
# source_token_emb_253                0.02
# target_token_emb_293                0.02
# source_token_emb_2                  0.02
# source_token_emb_194                0.02
# target_pos_tag_WRB                  0.02
# source_token_emb_70                 0.02
# target_token_emb_39                 0.02
# target_token_emb_123                0.02
# source_token_emb_275                0.01
# target_token_emb_137                0.01
# source_token_emb_252                0.01
# source_token_emb_239                0.01
# source_token_emb_161                0.01
# target_type_B-Condition Specification 0.01
# source_token_emb_237                0.01
# target_token_emb_220                0.01
# target_token_emb_294                0.01
# source_token_emb_155                0.01
# target_token_emb_53                 0.01
# target_token_emb_244                0.01
# source_token_emb_139                0.01
# target_pos_tag_NNP                  0.01
# target_token_emb_274                0.01
# target_token_emb_109                0.01
# source_token_emb_256                0.01
# target_token_emb_263                0.01
# source_pos_tag_VBG                  0.01
# source_token_emb_173                0.01
# source_token_emb_147                0.01
# document_name_doc-5.1               0.01
# target_token_emb_252                0.01
# document_name_doc-20.11 - credit risk assessment 0.01
# source_token_emb_299                0.01
# document_name_doc-6.4               0.01
# source_token_emb_36                 0.01
# source_token_emb_212                0.01
# target_token_emb_182                0.01
# source_token_emb_90                 0.01
# source_prev_tag_B-Further Specification 0.01
# source_token_emb_294                0.01
# target_token_emb_237                0.01
# target_token_emb_139                0.01
# source_token_emb_16                 0.01
# source_pos_tag_JJ                   0.01
# target_token_emb_64                 0.01
# target_token_emb_238                0.01
# target_token_emb_256                0.01
# target_token_emb_231                0.01
# document_name_doc-9.2               0.01
# target_token_emb_188                0.01
# target_token_emb_173                0.01
# source_token_emb_24                 0.01
# document_name_doc-9.5               0.01
# document_name_doc-6.3               0.01
# target_token_emb_122                0.01
# source_token_emb_23                 0.01
# source_token_emb_97                 0.01
# source_pos_tag_VBD                  0.01
# target_token_emb_142                0.01
# target_token_emb_55                 0.01
# target_token_emb_63                 0.01
# source_token_emb_74                 0.01
# target_token_emb_216                0.01
# source_token_emb_126                0.01
# source_token_emb_138                0.01
# target_token_emb_189                0.01
# source_token_emb_197                0.01
# source_token_emb_3                  0.01
# target_token_emb_257                0.01
# target_token_emb_194                0.01
# source_token_emb_169                0.01
# target_token_emb_277                0.01
# source_token_emb_285                0.01
# source_token_emb_150                0.01
# source_token_emb_129                0.01
# target_token_emb_66                 0.01
# document_name_doc-20.10 - ISP student 0.01
# target_token_emb_129                0.01
# source_token_emb_118                0.01
# source_token_emb_276                0.01
# document_name_doc-20.4 - procurement process 0.01
# target_token_emb_181                0.01
# source_token_emb_156                0.01
# source_token_emb_207                0.01
# target_token_emb_48                 0.01
# source_token_emb_284                0.01
# target_next_tag_B-Further Specification 0.01
# target_token_emb_74                 0.01
# target_token_emb_143                0.01
# document_name_doc-20.9 - complaint process model 0.01
# target_token_emb_19                 0.01
# target_token_emb_141                0.01
# target_token_emb_86                 0.0
# target_token_emb_84                 0.0
# source_token_emb_56                 0.0
# document_name_doc-8.1               0.0
# source_token_emb_148                0.0
# source_token_emb_292                0.0
# target_token_emb_18                 0.0
# target_token_emb_88                 0.0
# target_token_emb_208                0.0
# target_pos_tag_VBP                  0.0
# target_token_emb_242                0.0
# dependency_tags_[55, 61]            0.0
# source_token_emb_4                  0.0
# target_token_emb_20                 0.0
# source_token_emb_107                0.0
# target_token_emb_259                0.0
# source_token_emb_96                 0.0
# source_token_emb_177                0.0
# source_token_emb_189                0.0
# source_token_emb_261                0.0
# source_token_emb_181                0.0
# target_token_emb_103                0.0
# source_token_emb_15                 0.0
# document_name_doc-20.5 - edit pictures 0.0
# target_token_emb_205                0.0
# source_pos_tag_WRB                  0.0
# source_pos_tag_NNS                  0.0
# target_token_emb_70                 0.0
# target_token_emb_177                0.0
# target_token_emb_183                0.0
# source_token_emb_28                 0.0
# target_token_emb_255                0.0
# source_token_emb_282                0.0
# source_token_emb_106                0.0
# target_token_emb_90                 0.0
# target_token_emb_124                0.0
# document_name_doc-8.2               0.0
# source_token_emb_79                 0.0
# target_token_emb_16                 0.0
# source_token_emb_274                0.0
# target_token_emb_282                0.0
# target_token_emb_43                 0.0
# target_token_emb_179                0.0
# source_token_emb_5                  0.0
# target_token_emb_186                0.0
# target_pos_tag_TO                   0.0
# target_token_emb_26                 0.0
# target_token_emb_245                0.0
# source_token_emb_18                 0.0
# source_token_emb_34                 0.0
# source_token_emb_50                 0.0
# document_name_doc-8.3               0.0
# target_token_emb_288                0.0
# source_token_emb_175                0.0
# target_token_emb_148                0.0
# document_name_doc-20.14 - HR interview 0.0
# source_token_emb_283                0.0
# document_name_doc-20.8 - order shipping 0.0
# document_name_doc-3.7               0.0
# target_token_emb_155                0.0
# source_token_emb_113                0.0
# source_token_emb_218                0.0
# target_token_emb_61                 0.0
# target_token_emb_117                0.0
# target_token_emb_264                0.0
# source_token_emb_231                0.0
# target_token_emb_127                0.0
# target_token_emb_4                  0.0
# target_token_emb_113                0.0
# document_name_doc-20.15 - library request 0.0
# target_token_emb_102                0.0
# document_name_doc-3.8               0.0
# source_token_emb_243                0.0
# target_token_emb_92                 0.0
# target_token_emb_240                0.0
# source_pos_tag_MD                   0.0
# target_token_emb_154                0.0
# source_token_emb_120                0.0
# document_name_doc-3.2               0.0
# target_token_emb_230                0.0
# target_token_emb_160                0.0
# dependency_tags_[2, 14, 61]         0.0
# target_token_emb_140                0.0
# target_token_emb_172                0.0
# source_token_emb_7                  0.0
# source_token_emb_240                0.0
# target_token_emb_299                0.0
# dependency_tags_[11, 61]            0.0
# source_token_emb_61                 0.0
# source_token_emb_151                0.0
# source_token_emb_166                0.0
# source_token_emb_116                0.0
# source_token_emb_8                  0.0
# document_name_doc-6.2               0.0
# source_token_emb_81                 0.0
# source_token_emb_142                0.0
# source_token_emb_54                 0.0
# dependency_tags_[61, 14]            0.0
# target_token_emb_32                 0.0
# target_pos_tag_MD                   0.0
# dependency_tags_[61, 41]            0.0
# target_token_emb_82                 0.0
# target_token_emb_29                 0.0
# target_token_emb_106                0.0
# target_token_emb_100                0.0
# source_pos_tag_EX                   0.0
# dependency_tags_[55, 50, 61, 4]     0.0
# dependency_tags_[55, 61, 41]        0.0
# target_token_emb_147                0.0
# document_name_doc-10.5              0.0
# document_name_doc-10.3              0.0
# target_token_emb_44                 0.0
# dependency_tags_[55, 3, 50, 61]     0.0
# dependency_tags_[42, 61]            0.0
# target_token_emb_50                 0.0
# dependency_tags_[22, 1, 62]         0.0
# target_token_emb_156                0.0
# target_token_emb_268                0.0
# target_token_emb_243                0.0
# dependency_tags_[42, 61, 14]        0.0
# dependency_tags_[55, 60, 61]        0.0
# source_pos_tag_UH                   0.0
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9881
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7208
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.9881
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7958
# actor recipient                     0.7536
# flow                                0.4638
# further specification               0.7879
# no_relation                         0.9947
# same gateway                        0.3333
# uses                                0.9163
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# ------------------------
#
# Aggregated metrics fold 5
#
# Micro F1        Macro F1        Weighted F1
# 0.9890          0.7208          0.9881
#
# ------------------------
# ------------------------
#
# Crossvalidation finished
#
# Best fold 1
#
# ------------------------
# ------------------------
#
# Average F1 across all folds:
#
# Micro F1        Macro F1        Weighted F1
# 0.9899          0.7636          0.9890
#
# ------------------------
# ------------------------
# AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS
#
# Label                               Precision       Recall          F1
#
# actor performer                     0.8503          0.7693          0.8074
# actor recipient                     0.8834          0.761           0.8153
# flow                                0.6704          0.4027          0.5024
# further specification               0.9005          0.781           0.8355
# no_relation                         0.9929          0.9972          0.9951
# same gateway                        0.6989          0.3899          0.4617
# uses                                0.9211          0.9357          0.928
#
# ------------------------
# ------------------------
# CLASS WEIGHTS USED

# %% [markdown]
# ##6.4. Random Over Sampling (ROS)
#
# ###6.4.1 ROS with Negative Sampling
#
# We perform a crossvalidation on the catboost model that was trained using the negative sampling data created in section 6.2 and enriched it with random samples of 'flow'. For implementation of the crossvalidation and the parameters see section 2.4.

# %%
best_model_RANDOMOVERSAMPLE_neg_sample = crossvalidation_RANDOMOVERSAMPLE(data_negative_sampling, SEED, test_neg, test_size, folds, use_class_weights=True)
# Save the best model to a file
model_path = "/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TRAINED_CATBOOST_MODEL/best_catboost_model_using_RANDOMOVERSAMPLE_neg_sample.cbm"
best_model_RANDOMOVERSAMPLE_neg_sample.save_model(model_path, format="cbm")
# Out:
# <ipython-input-11-09bcef8f98c5>:27: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]
# ---------------------------------------
#
# Training fold 1...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   17.1
# target_type                         13.73
# source_type                         12.76
# token_distance                      6.2
# target_pos_tag                      5.18
# target_token_ID                     5.15
# source_pos_tag                      4.63
# target_sentence_ID                  4.29
# source_token                        4.16
# target_next_tag                     4.0
# source_next_tag                     3.99
# source_token_ID                     3.95
# source_sentence_ID                  3.59
# target_token                        3.29
# target_prev_tag                     2.97
# source_prev_tag                     2.62
# document_name                       2.39
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9873
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7548
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8715
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7619
# actor recipient                     0.7654
# flow                                0.5577
# further specification               0.9189
# no_relation                         0.9932
# same gateway                        0.375
# uses                                0.9113
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 1
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8182          0.7129          0.7619          101
# actor recipient                     0.6889          0.8611          0.7654          36
# flow                                0.4399          0.7619          0.5577          168
# further specification               0.8500          1.0000          0.9189          17
# no_relation                         0.9964          0.9901          0.9932          20120
# same gateway                        0.6000          0.2727          0.3750          11
# uses                                0.8692          0.9576          0.9113          118
# ------------------------
#
# Aggregated metrics fold 1
#
# Micro F1        Macro F1        Weighted F1
# 0.9860          0.7548          0.9873
#
# ---------------------------------------
#
# Training fold 2...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# source_type                         18.13
# sentence_distance                   13.4
# target_type                         12.4
# token_distance                      7.16
# target_token_ID                     5.94
# source_token_ID                     5.72
# target_pos_tag                      4.61
# source_pos_tag                      4.56
# source_next_tag                     4.47
# target_sentence_ID                  4.37
# source_sentence_ID                  3.29
# target_prev_tag                     3.28
# target_next_tag                     3.04
# document_name                       2.8
# target_token                        2.46
# source_token                        2.39
# source_prev_tag                     1.98
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9872
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7942
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8596
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7166
# actor recipient                     0.7294
# flow                                0.5484
# further specification               0.9189
# no_relation                         0.9933
# same gateway                        0.7368
# uses                                0.9157
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 2
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.7791          0.6634          0.7166          101
# actor recipient                     0.6327          0.8611          0.7294          36
# flow                                0.4474          0.7083          0.5484          168
# further specification               0.8500          1.0000          0.9189          17
# no_relation                         0.9960          0.9906          0.9933          20120
# same gateway                        0.8750          0.6364          0.7368          11
# uses                                0.8702          0.9661          0.9157          118
# ------------------------
#
# Aggregated metrics fold 2
#
# Micro F1        Macro F1        Weighted F1
# 0.9861          0.7942          0.9872
#
# ---------------------------------------
#
# Training fold 3...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# source_type                         16.23
# sentence_distance                   15.28
# target_type                         10.7
# token_distance                      7.16
# target_pos_tag                      6.23
# target_token_ID                     5.1
# source_next_tag                     4.69
# source_token_ID                     4.65
# target_next_tag                     4.62
# target_sentence_ID                  4.03
# source_pos_tag                      4.02
# source_sentence_ID                  3.88
# document_name                       3.19
# source_token                        2.79
# target_token                        2.6
# target_prev_tag                     2.42
# source_prev_tag                     2.4
# dependency_tags                     0.0
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9876
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7866
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8802
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7435
# actor recipient                     0.725
# flow                                0.5727
# further specification               0.9189
# no_relation                         0.9934
# same gateway                        0.625
# uses                                0.9274
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 3
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.7889          0.7030          0.7435          101
# actor recipient                     0.6591          0.8056          0.7250          36
# flow                                0.4505          0.7857          0.5727          168
# further specification               0.8500          1.0000          0.9189          17
# no_relation                         0.9966          0.9902          0.9934          20120
# same gateway                        1.0000          0.4545          0.6250          11
# uses                                0.8846          0.9746          0.9274          118
# ------------------------
#
# Aggregated metrics fold 3
#
# Micro F1        Macro F1        Weighted F1
# 0.9864          0.7866          0.9876
#
# ---------------------------------------
#
# Training fold 4...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   14.97
# target_type                         12.78
# source_type                         12.64
# token_distance                      6.88
# target_token_ID                     5.56
# source_next_tag                     5.24
# source_pos_tag                      5.17
# target_sentence_ID                  5.13
# source_token_ID                     5.1
# target_pos_tag                      4.97
# source_token                        4.38
# source_sentence_ID                  4.14
# target_token                        4.04
# target_next_tag                     2.63
# document_name                       2.29
# target_prev_tag                     2.12
# source_prev_tag                     1.94
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9881
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7885
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8713
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7435
# actor recipient                     0.7692
# flow                                0.5747
# further specification               0.9189
# no_relation                         0.9938
# same gateway                        0.5882
# uses                                0.9312
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 4
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.7889          0.7030          0.7435          101
# actor recipient                     0.7143          0.8333          0.7692          36
# flow                                0.4682          0.7440          0.5747          168
# further specification               0.8500          1.0000          0.9189          17
# no_relation                         0.9964          0.9913          0.9938          20120
# same gateway                        0.8333          0.4545          0.5882          11
# uses                                0.8915          0.9746          0.9312          118
# ------------------------
#
# Aggregated metrics fold 4
#
# Micro F1        Macro F1        Weighted F1
# 0.9872          0.7885          0.9881
#
# ---------------------------------------
#
# Training fold 5...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   14.47
# target_type                         14.33
# source_type                         13.14
# target_token_ID                     6.55
# token_distance                      5.91
# target_pos_tag                      5.27
# source_token_ID                     5.08
# source_pos_tag                      4.81
# target_sentence_ID                  4.75
# source_next_tag                     4.05
# source_token                        4.0
# source_sentence_ID                  3.58
# target_next_tag                     3.49
# document_name                       2.92
# target_token                        2.73
# source_prev_tag                     2.51
# target_prev_tag                     2.39
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.987
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7699
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8701
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.72
# actor recipient                     0.75
# flow                                0.5565
# further specification               0.8718
# no_relation                         0.993
# same gateway                        0.5714
# uses                                0.9268
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 5
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8514          0.6238          0.7200          101
# actor recipient                     0.6818          0.8333          0.7500          36
# flow                                0.4290          0.7917          0.5565          168
# further specification               0.7727          1.0000          0.8718          17
# no_relation                         0.9964          0.9896          0.9930          20120
# same gateway                        0.6000          0.5455          0.5714          11
# uses                                0.8906          0.9661          0.9268          118
# ------------------------
#
# Aggregated metrics fold 5
#
# Micro F1        Macro F1        Weighted F1
# 0.9856          0.7699          0.9870
#
# ------------------------
# ------------------------
#
# Crossvalidation finished
#
# Best fold 2
#
# ------------------------
# ------------------------
#
# Average F1 across all folds:
#
# Micro F1        Macro F1        Weighted F1
# 0.9863          0.7788          0.9874
#
# ------------------------
# ------------------------
# AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS
#
# Label                               Precision       Recall          F1
#
# actor performer                     0.8053          0.6812          0.7371
# actor recipient                     0.6753          0.8389          0.7478
# flow                                0.447           0.7583          0.562
# further specification               0.8345          1.0             0.9095
# no_relation                         0.9964          0.9903          0.9933
# same gateway                        0.7817          0.4727          0.5793
# uses                                0.8812          0.9678          0.9225
#
# ------------------------
# ------------------------
# CLASS WEIGHTS USED

# %% [markdown]
# ###6.4.2. ROS on baseline data
#
# Crossvalidation was done using the baseline data that is enriched using ROS for the 'flow' relation only.

# %%
best_model_RANDOMOVERSAMPLE = crossvalidation_RANDOMOVERSAMPLE(total, SEED, "ignore", test_size, folds, use_class_weights=True)
# Save the best model to a file
model_path = "/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TRAINED_CATBOOST_MODEL/best_catboost_model_using_RANDOMOVERSAMPLE.cbm"
best_model_RANDOMOVERSAMPLE.save_model(model_path, format="cbm")
# Out:
# <ipython-input-11-09bcef8f98c5>:27: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   categorical_features_indices = [i for i, typ in enumerate(data_features.dtypes) if typ == 'object' or pd.api.types.is_categorical_dtype(data_features.iloc[:, i])]
# ---------------------------------------
#
# Training fold 1...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   15.49
# target_type                         12.97
# source_type                         12.7
# token_distance                      7.01
# target_token_ID                     6.47
# target_sentence_ID                  6.25
# source_token_ID                     5.31
# source_token                        4.97
# target_pos_tag                      4.62
# source_pos_tag                      4.28
# source_next_tag                     3.97
# source_sentence_ID                  3.72
# target_prev_tag                     2.82
# source_prev_tag                     2.57
# document_name                       2.5
# target_next_tag                     2.48
# target_token                        1.88
# dependency_tags                     0.0
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9892
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.8018
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.843
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7667
# actor recipient                     0.8352
# flow                                0.5625
# further specification               0.9444
# no_relation                         0.9946
# same gateway                        0.5625
# uses                                0.9465
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 1
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8415          0.7041          0.7667          98
# actor recipient                     0.9048          0.7755          0.8352          49
# flow                                0.5103          0.6266          0.5625          158
# further specification               0.9444          0.9444          0.9444          18
# no_relation                         0.9951          0.9942          0.9946          20113
# same gateway                        0.5294          0.6000          0.5625          15
# uses                                0.9350          0.9583          0.9465          120
# ------------------------
#
# Aggregated metrics fold 1
#
# Micro F1        Macro F1        Weighted F1
# 0.9889          0.8018          0.9892
#
# ---------------------------------------
#
# Training fold 2...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   15.19
# source_type                         13.92
# target_type                         11.19
# token_distance                      7.62
# source_sentence_ID                  5.18
# source_token_ID                     5.12
# target_token_ID                     5.06
# target_sentence_ID                  4.95
# target_token                        4.94
# target_pos_tag                      4.89
# source_pos_tag                      4.46
# source_next_tag                     4.11
# source_token                        3.66
# target_next_tag                     3.16
# target_prev_tag                     2.23
# source_prev_tag                     2.19
# document_name                       2.12
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9898
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7555
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.83
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.8077
# actor recipient                     0.6667
# flow                                0.6224
# further specification               0.8
# no_relation                         0.9951
# same gateway                        0.4444
# uses                                0.9524
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 2
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8571          0.7636          0.8077          110
# actor recipient                     0.7692          0.5882          0.6667          34
# flow                                0.6205          0.6242          0.6224          165
# further specification               0.8235          0.7778          0.8000          18
# no_relation                         0.9943          0.9959          0.9951          20103
# same gateway                        1.0000          0.2857          0.4444          14
# uses                                0.9600          0.9449          0.9524          127
# ------------------------
#
# Aggregated metrics fold 2
#
# Micro F1        Macro F1        Weighted F1
# 0.9900          0.7555          0.9898
#
# ---------------------------------------
#
# Training fold 3...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   14.22
# target_type                         12.81
# source_type                         10.32
# source_pos_tag                      7.56
# target_token_ID                     5.88
# token_distance                      5.88
# target_pos_tag                      5.48
# source_token_ID                     4.96
# source_sentence_ID                  4.69
# source_token                        4.5
# target_sentence_ID                  4.45
# source_next_tag                     4.34
# target_token                        3.48
# target_next_tag                     3.31
# source_prev_tag                     2.79
# target_prev_tag                     2.74
# document_name                       2.57
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9903
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.8035
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8424
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.8122
# actor recipient                     0.8
# flow                                0.6516
# further specification               0.9474
# no_relation                         0.9954
# same gateway                        0.5333
# uses                                0.885
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 3
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8889          0.7477          0.8122          107
# actor recipient                     0.7568          0.8485          0.8000          33
# flow                                0.6461          0.6571          0.6516          175
# further specification               1.0000          0.9000          0.9474          10
# no_relation                         0.9951          0.9957          0.9954          20125
# same gateway                        1.0000          0.3636          0.5333          11
# uses                                0.8621          0.9091          0.8850          110
# ------------------------
#
# Aggregated metrics fold 3
#
# Micro F1        Macro F1        Weighted F1
# 0.9904          0.8035          0.9903
#
# ---------------------------------------
#
# Training fold 4...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   14.24
# source_type                         13.82
# target_type                         13.46
# source_token_ID                     7.01
# target_token_ID                     6.54
# token_distance                      6.01
# source_token                        5.53
# source_pos_tag                      4.89
# target_sentence_ID                  4.61
# target_pos_tag                      4.57
# source_sentence_ID                  4.39
# source_next_tag                     3.75
# target_prev_tag                     2.74
# target_next_tag                     2.72
# source_prev_tag                     2.09
# document_name                       1.98
# target_token                        1.65
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9912
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.8298
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8626
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.8287
# actor recipient                     0.7931
# flow                                0.6291
# further specification               0.9
# no_relation                         0.9957
# same gateway                        0.7143
# uses                                0.9478
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 4
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8242          0.8333          0.8287          90
# actor recipient                     0.8214          0.7667          0.7931          30
# flow                                0.6235          0.6347          0.6291          167
# further specification               1.0000          0.8182          0.9000          22
# no_relation                         0.9956          0.9958          0.9957          20130
# same gateway                        1.0000          0.5556          0.7143          9
# uses                                0.9365          0.9593          0.9478          123
# ------------------------
#
# Aggregated metrics fold 4
#
# Micro F1        Macro F1        Weighted F1
# 0.9912          0.8298          0.9912
#
# ---------------------------------------
#
# Training fold 5...
#
# ---------------------------------------
#
# Training succesfully finished!
#
# ---------------------------------------
#
#
# Getting feature importances...
#
# Feature                             Score
#
# sentence_distance                   14.17
# target_type                         12.84
# source_type                         12.4
# source_token_ID                     7.06
# token_distance                      6.2
# target_token_ID                     6.04
# target_sentence_ID                  5.41
# source_pos_tag                      5.06
# source_token                        4.56
# target_pos_tag                      4.54
# source_next_tag                     3.86
# target_next_tag                     3.43
# source_sentence_ID                  3.38
# target_token                        3.01
# source_prev_tag                     2.87
# document_name                       2.62
# target_prev_tag                     2.52
# dependency_tags                     0.01
#
# ---------------------------------------
#
# Weighted F1 Score for all predicted labels: 0.9905
#
# ---------------------------------------
#
# Macro F1 Score for all predicted labels: 0.7798
#
# ---------------------------------------
#
# Weighted F1 Score (excluding "no_relation"): 0.8483
#
# ---------------------------------------
#
# Label                               F1
#
# actor performer                     0.7807
# actor recipient                     0.7941
# flow                                0.6348
# further specification               0.9143
# no_relation                         0.9955
# same gateway                        0.4
# uses                                0.9391
#
# ------------------------
#
# Training finished, fetching metrics on validation set...
#
# ------------------------
#
# Metrics per label for fold 5
#
# Label                               Precision       Recall          F1              Support
#
# actor performer                     0.8295          0.7374          0.7807          99
# actor recipient                     0.8182          0.7714          0.7941          35
# flow                                0.6243          0.6457          0.6348          175
# further specification               0.9412          0.8889          0.9143          18
# no_relation                         0.9955          0.9954          0.9955          20128
# same gateway                        0.3333          0.5000          0.4000          4
# uses                                0.9076          0.9730          0.9391          111
# ------------------------
#
# Aggregated metrics fold 5
#
# Micro F1        Macro F1        Weighted F1
# 0.9905          0.7798          0.9905
#
# ------------------------
# ------------------------
#
# Crossvalidation finished
#
# Best fold 4
#
# ------------------------
# ------------------------
#
# Average F1 across all folds:
#
# Micro F1        Macro F1        Weighted F1
# 0.9902          0.7941          0.9902
#
# ------------------------
# ------------------------
# AVERAGE METRICS PER LABEL ACCROSS ALL FOLDS
#
# Label                               Precision       Recall          F1
#
# actor performer                     0.8482          0.7572          0.7992
# actor recipient                     0.8141          0.7501          0.7778
# flow                                0.6049          0.6377          0.6201
# further specification               0.9418          0.8659          0.9012
# no_relation                         0.9951          0.9954          0.9953
# same gateway                        0.7725          0.461           0.5309
# uses                                0.9202          0.9489          0.9342
#
# ------------------------
# ------------------------
# CLASS WEIGHTS USED

# %% [markdown]
# #6.5. CONCLUSION
#
# Among the various sampling strategies tested, ***ROS on baseline data*** resulted in the highest Macro F1 score of ***0.7921***, indicating the best overall performance across all classes. This approach also performed best for the 'flow' class specifically, with an F1 score of ***0.6200***.
#
# For the 'flow' class, the ROS on baseline data strategy yielded the highest F1 score of 0.6200, followed closely by the baseline approach with an F1 score of 0.6022.
#
# The baseline data and negative sampling only approaches provided balanced performance, with high Macro F1 scores (0.7795 and 0.7429 respectively) and moderately good performance for the 'flow' class (0.6022 and 0.6039 respectively).

# %% [markdown]
# #7. Model for Pipeline Integration
#
# In this section we select the model from the best fold from the crossvalidation using the optimal method obtained from section 6 to be used in the pipeline.

# %% [markdown]
# ##7.1 Data Inputs
#
# This subsection will manipulate the data to keep a separate test document.

# %% [markdown]
# ###7.1.1 Training Model excluding 6DOCS
#
# For the purposes of pipeline testing we exclude 6 documents from model training.

# %%
# Define the paths to the PET and LESCHNEIDER data, you get this data by running "Feature Generation for CatBoost".
path1 = '/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TESTING DATA/RE_TRAINING_DATA/total_relation_entity_pairs_DEPENDENCY_CONTEXT_md_PET1.1.csv' #feature of neighbours before and after
path2 = '/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TESTING DATA/RE_TRAINING_DATA/total_relation_entity_pairs_DEPENDENCY_CONTEXT_md_LESCHNEIDER.csv'

df_PET = pd.read_csv(path1)
df_LESCHNEIDER = pd.read_csv(path2)


total = pd.concat([df_PET, df_LESCHNEIDER], ignore_index=True)

# Select the document name you want to remove

doc_excl_list = ['doc-3.1', 'doc-9.3', 'doc-8.2', 'doc-10.7', 'doc-20.5 - edit pictures', 'doc-10.12']

test_doc = total[total['document_name'].isin(doc_excl_list)]
rel_pipeline_data = total[~total['document_name'].isin(doc_excl_list)]
print(test_doc[test_doc['document_name']== 'doc-8.2'])

if not test_doc.empty and not rel_pipeline_data.empty:
  print('data loaded')

# %% [markdown]
# ###7.1.2 Training Model on FULL DATA
#
# For the purpose of training a demo pipeline, we trained the model on the full data.

# %%
# Define the paths to the PET and LESCHNEIDER data, you get this data by running "Feature Generation for CatBoost".
path1 = '/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TESTING DATA/RE_TRAINING_DATA/total_relation_entity_pairs_DEPENDENCY_CONTEXT_md_PET1.1.csv' #feature of neighbours before and after
path2 = '/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/TESTING DATA/RE_TRAINING_DATA/total_relation_entity_pairs_DEPENDENCY_CONTEXT_md_LESCHNEIDER.csv'

df_PET = pd.read_csv(path1)
df_LESCHNEIDER = pd.read_csv(path2)


total = pd.concat([df_PET, df_LESCHNEIDER], ignore_index=True)

# %% [markdown]
# ##7.2 Model Training and Saving
#
# Using this data we now crossvalidate and chose the best model. This model is then saved for use in our pipeline. You have to do this twice, once for the testing pipeline, and once for the demo pipeline.

# %%
folds = 5
test_size = 0.2
best_model_ROS = crossvalidation_RANDOMOVERSAMPLE(total, SEED, "ignore", test_size, folds, use_class_weights=True)
# Save the best model to a file
model_path = "/content/drive/MyDrive/THESIS/CODING/NAM_TESTING/PIPELINE/RE MODELS/best_catboost_ROS_PIPELINE_FULL_DATA.cbm"
best_model_ROS.save_model(model_path, format="cbm")
